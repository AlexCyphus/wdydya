# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", 50, "display.max_columns", None)

# %%
# Declare all global variables as a class and reset them
# This is so we don't have to globally declare the variables in every function

languages = ["DE","ES","FR","IT","JP","KO","PT","RU","ZHS","ZHT"]

def reset_values(): 
    class glb:
        convo_undeveloped, not_expected, scammers, no_partner, no_help = 0, 0, 0, 0, 0
        messages_not_delivered, photos_not_delivered, audio_not_play, crashed, interpals, other_app, all_android, all_ios, lang_total = 0, 0, 0, 0,0, 0, 0, 0, 0
        technical_ios, too_much_space, too_much_space_android, too_much_space_ios, drains_battery = 0, 0, 0, 0, 0
        drains_battery_android, drains_battery_ios, push_notifications, push_notifications_android, push_notifications_ios = 0, 0, 0, 0, 0
        confusing, not_learning, no_time, change_profile, new_account  = 0, 0, 0, 0, 0
        beginner, dating, no_pay, different_app, hellotalk = 0, 0, 0, 0, 0
        speaky, fylp, italki, opentalk, lingbe = 0, 0, 0, 0, 0
        bilingua, hellopal, duolingo, fylp , ablo = 0, 0, 0, 0, 0
        other_reason, no_notifications, orderless_messages, audio_send_fail, audio_video_quality, other_technical = 0, 0, 0, 0, 0, 0
        too_many_msgs, too_many_calls, offended, technical, technical_android, one_lang = 0, 0, 0, 0, 0, 0
    
def print_results(specific="none"):

    # if analyzing languages one by one
    if specific == "device":
        print "----------" + device + "----------"
    if specific == "language":
        print "----------" + lang + "----------"
    print "-"
    print "Didn't develop into meaningful convo: " + str(glb.convo_undeveloped)
    print "The app is not what I expected: " + str(glb.not_expected)
    print "There were too many scammers // fake profiles: " + str(glb.scammers)
    print "I couldn't find anyone to talk to: " + str(glb.no_partner)
    print "The app didn't help me much with my language learning: " + str(glb.no_help)
    print "I received too many messages on Tandem: " + str(glb.too_many_msgs)
    print "I received too many calls on Tandem that I didn't want to take: " + str(glb.too_many_calls)
    print "Someone offended or annoyed me: " + str(glb.offended)
    print "I had technical problems using the app: " + str(glb.technical) + ":Android: " + str(glb.technical_android) + " // " + str(float(glb.technical_android)/glb.all_android * 100) + "% :"  + "iOS: " + str(glb.technical_ios) + " // " + str(float(glb.technical_ios)/glb.all_ios * 100) + "%"
    print "App drains battery: " + str(glb.drains_battery) + ":Android: " + str(glb.drains_battery_android) + " // " + str(float(glb.drains_battery_android)/glb.all_android * 100) + "%:" + "iOS: " + str(glb.drains_battery_ios) + " // " + str(float(glb.drains_battery_ios)/glb.all_ios * 100) + "%"
    print "Too many push notifications: " + str(glb.push_notifications) + ":Android: " + str(glb.push_notifications_android) + " // " + str(float(glb.push_notifications_android)/glb.all_android * 100) + "%"+":iOS: " + str(glb.push_notifications_ios) + " // " + str(float(glb.push_notifications_ios)/glb.all_ios * 100) + "%"
    print "The app was confusing: " + str(glb.confusing)
    print "Not currently learning a lang: " + str(glb.not_learning)
    print "Don't have time: " + str(glb.no_time)
    print "Want to change profile info: " + str(glb.change_profile)
    print "Want to start a new account: " + str(glb.new_account)
    print "I am still a beginner: " + str(glb.beginner)
    print "It felt like a dating app: " + str(glb.dating)
    print "Didn't want to pay for pro: " + str(glb.no_pay)
    print "Using a different app: " + str(glb.different_app)
    print "Mainly one language: " + str(glb.one_lang)
    print "Other: " + str(glb.other_reason)
    print "-"
    print "HelloTalk: " + str(glb.hellotalk)
    print "Speaky: " + str(glb.speaky)
    print "iTalki: " + str(glb.italki)
    print "OpenTalk: " + str(glb.opentalk)
    print "Lingebe: " + str(glb.lingbe)
    print "Bilingua: " + str(glb.bilingua)
    print "HelloPal: " + str(glb.hellopal)
    print "Duolingo: " + str(glb.duolingo)
    print "Fylp: " + str(glb.fylp)
    print "Ablo: " + str(glb.ablo)
    print "InterPals: " + str(glb.interpals)
    print "Other app: " + str(glb.other_app + 1)
    print "----- Technical ----"
    print "Some messages not delivered: " + str(glb.messages_not_delivered)
    print "Some photos not delivered: " + str(glb.photos_not_delivered)
    print "Audio messages wouldn't play: " + str(glb.audio_not_play)
    print "The app froze or crashed: " + str(glb.crashed)
    print "I didn't receive notifications: " + str(glb.no_notifications)
    print "Messages or chats were out of order: " + str(glb.orderless_messages)
    print "Audio messages failed to send: " + str(glb.audio_send_fail)
    print "Audio or video quality was really bad: " + str(glb.audio_video_quality)
    print "Other technical problem: " + str(glb.other_technical)
    print "Total: " + str(glb.lang_total)
    print "Android: " + str(glb.all_android)
    print "iOS: " + str(glb.all_ios)

# %%
def analyse(dataframe):

    #Read and split file into Android + iOS
    filename = dataframe + ".xlsx"
    df = pd.read_excel(filename)

    is_android = df.iloc[:,30] == "Android"
    df_android = df[is_android]

    is_ios = df.iloc[:,30] != "Android"
    df_ios = df[is_ios]

    # Count number of device specific responses
    glb.all_android += df_android["#"].count()
    glb.all_ios += df_ios["#"].count()
    glb.lang_total += df["#"].count()

    # Counting specific entries for entire dataframe (for this language)

    # 1 My conversations on Tandem rarely developed into a meaningful conversation
    b = df.iloc[:, 1]
    glb.convo_undeveloped += b.count()

    # 2 The app is not what I expected
    c = df.iloc[:, 2]
    glb.not_expected += c.count()

    # 3 There were too many scammers and fake profiles
    d = df.iloc[:,3]
    glb.scammers += d.count()

    # 4 I couldn't find anyone to talk to
    e = df.iloc[:,4]
    glb.no_partner += e.count()

    # 5 The app didn't help me much with my language learning
    f = df.iloc[:,5]
    glb.no_help += f.count()

    # 6 I received too many messages on Tandem
    g = df.iloc[:,6]
    glb.too_many_msgs += g.count()

    # 7 I received too many calls on Tandem that I didn't want to take
    h = df.iloc[:,7]
    glb.too_many_calls += h.count()

    # 8 Someone offended or annoyed me
    i = df.iloc[:,8]
    glb.offended += i.count()

    # 9 I had technical problems using the app

    # Total across iOS + Android
    j = df.iloc[:,9]
    glb.technical += j.count()

    # Seperated by iOS and Android
    j_android = df_android.iloc[:,9]
    glb.technical_android += j_android.count()
    j_ios = df_ios.iloc[:,9]
    glb.technical_ios += j_ios.count()

    # 10 The app takes too much space on my device

    # Total across iOS + Android
    k = df.iloc[:,10]
    glb.too_much_space += k.count()

    # Seperated by iOS and Android
    k_android = df_android.iloc[:,10]
    glb.too_much_space_android += k_android.count()
    k_ios = df_ios.iloc[:,10]
    glb.too_much_space_ios += k_ios.count()

    # 11 The app drains my battery

    # Total across iOS + Android
    l = df.iloc[:,11]
    glb.drains_battery += l.count()

    # Seperated by iOS and Android
    l_android = df_android.iloc[:,11]
    glb.drains_battery_android += l_android.count()
    l_ios = df_ios.iloc[:,11]
    glb.drains_battery_ios += l_ios.count()

    # 12 The app sent me too many push notifications, it got annoying

    # Total across iOS + Android
    m = df.iloc[:,12]
    glb.push_notifications += m.count()

    # Seperated by iOS and Android
    m_android = df_android.iloc[:,12]
    glb.push_notifications_android += m_android.count()
    m_ios = df_ios.iloc[:,12]
    glb.push_notifications_ios += m_ios.count()

    # 13 The app was confusing, I didn't understand how to use it
    n = df.iloc[:,13]
    glb.confusing += n.count()

    # 14 I'm not learning a language anymore
    o = df.iloc[:,14]
    glb.not_learning += o.count()

    # 15 I don't have enough time for the app
    p = df.iloc[:,15]
    glb.no_time += p.count()

    # 16 I want to change my profile information
    q = df.iloc[:,16]
    glb.change_profile += q.count()

    # 17 I want to start a new account
    r = df.iloc[:,17]
    glb.new_account += r.count()

    # 18 I'm a beginner and don't speak well enough yet to have a proper language exchange
    s = df.iloc[:,18]
    glb.beginner += s.count()

    # 19 It felt like a dating app
    t = df.iloc[:,19]
    glb.dating += t.count()

    # 20 I don't want to pay for Tandem and the free features are not enough for me
    u = df.iloc[:,20]
    glb.no_pay += u.count()

    # 21 I'm using a different app instead of Tandem
    v = df.iloc[:,21]
    glb.different_app += v.count()

    # 22 My conversations were almost exclusively in one language
    w = df.iloc[:,22]
    glb.one_lang += w.count()

    # 23 Other (reason)
    x = df.iloc[:,23]
    glb.other_reason += x.count()

    # * 24 You mentioned that you're using a different app instead of Tandem. Which app are you using?
    y = df.iloc[:,24]

    glb.hellotalk += y[(y == "HelloTalk") == True].count()
    glb.speaky += y[(y == "Speaky") == True].count()
    glb.fylp += y[(y == "Fylp") == True].count()
    glb.italki += y[(y == "iTalki") == True].count()
    glb.opentalk += y[(y == "Opentalk") == True].count()
    glb.lingbe += y[(y == "Lingbe") == True].count()
    glb.bilingua += y[(y == "Bilingua") == True].count()
    glb.hellopal += y[(y == "Hello Pal") == True].count()
    glb.duolingo += y[(y == "Duolingo") == True].count()
    glb.ablo += y[(y == "Ablo") == True].count()
    glb.interpals += y[(y == "InterPals") == True].count()

    # 25 Other (app)
    z = df.iloc[:,25]
    glb.other_app += w.count()

    # 26 Some of the messages that I sent weren’t delivered
    aa = df.iloc[:,26]
    glb.messages_not_delivered += aa.count()

    # 27 Some of the photos that I sent weren’t delivered
    ab = df.iloc[:,27]
    glb.photos_not_delivered += ab.count()

    # 28 I couldn’t play audio messages that my partners had sent to me
    ac = df.iloc[:,28]
    glb.audio_not_play += ac.count()

    # 29 The app frequently crashed or froze
    ad = df.iloc[:,29]
    glb.crashed += ad.count()

    # 30 I didn’t get notifications for new messages or chats
    ae = df.iloc[:,30]
    glb.no_notifications += ae.count()

    # 31 My messages or chats were out of order
    af = df.iloc[:,31]
    glb.orderless_messages += af.count()

    # 32 I couldn’t send audio messages to my partners
    ag = df.iloc[:,32]
    glb.audio_send_fail += ag.count()

    # 33 The video or audio call quality was really bad
    ah = df.iloc[:,33]
    glb.audio_video_quality += ah.count()

    # Other technical problem
    ai = df.iloc[:,34]
    glb.other_technical += ai.count()

    # Print total entries in dataframe
    print "Total " + str(dataframe) + ": " + str(df["#"].count())

# %%
# loop through 11 needed dataframes. Throw up specific error if one is missing.
reset_values()

# analyze all languages together
for lang in languages:
    analyse(lang)

print_results("none")
reset_values()
# Out:
# Total DE: 3042
# Total ES: 13260
# Total FR: 4433
# Total IT: 2761
# Total JP: 4243
# Total KO: 3139
# Total PT: 8721
# Total RU: 5526
# Total ZHS: 2904
# Total ZHT: 387
# -
# Didn't develop into meaningful convo: 31340
# The app is not what I expected: 19225
# There were too many scammers // fake profiles: 9300
# I couldn't find anyone to talk to: 37105
# The app didn't help me much with my language learning: 15590
# I received too many messages on Tandem: 9075
# I received too many calls on Tandem that I didn't want to take: 4585
# Someone offended or annoyed me: 7940
# I had technical problems using the app: 3855:Android: 2650 // 1.70002566076% :iOS: 1205 // 1.39791183295%
# App drains battery: 7690:Android: 4810 // 3.08570695407%:iOS: 2880 // 3.34106728538%
# Too many push notifications: 4845:Android: 2945 // 1.88927380036%:iOS: 1900 // 2.20417633411%
# The app was confusing: 9035
# Not currently learning a lang: 13800
# Don't have time: 41620
# Want to change profile info: 7960
# Want to start a new account: 23105
# I am still a beginner: 21825
# It felt like a dating app: 26545
# Didn't want to pay for pro: 15410
# Using a different app: 6945
# Mainly one language: 9115
# Other: 5625
# -
# HelloTalk: 0
# Speaky: 10
# iTalki: 0
# OpenTalk: 0
# Lingebe: 0
# Bilingua: 0
# HelloPal: 0
# Duolingo: 240
# Fylp: 0
# Ablo: 85
# InterPals: 15
# Other app: 9116
# ----- Technical ----
# Some messages not delivered: 3855
# Some photos not delivered: 41610
# Audio messages wouldn't play: 15570
# The app froze or crashed: 176455
# I didn't receive notifications: 155905
# Messages or chats were out of order: 242080
# Audio messages failed to send: 242080
# Audio or video quality was really bad: 242080
# Other technical problem: 0
# Total: 242080
# Android: 155880
# iOS: 86200

# %%
# get "Other" answers
languages = ["EN","DE","ES","FR","IT","JP","KO","PT","RU","ZHS","ZHT"]

for lang in languages:
    filename = lang + ".xlsx"
    df = pd.read_excel(filename)
    other = df.iloc[:,23]
    for item in other:
        item = unicode(item)
        if item != "nan":
            print item
# Out:
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# iTalki
# iTalki
# HelloTalk
# Bilingua
# HelloTalk
# Opentalk
# Hello Pal
# Bilingua
# iTalki
# HelloTalk
# HelloTalk
# iTalki
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# Fylp
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Hello Pal
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Lingbe
# Lingbe
# Speaky
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# Bilingua
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# Hello Pal
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# Bilingua
# iTalki
# Bilingua
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Bilingua
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# iTalki
# Speaky
# Speaky
# HelloTalk
# HelloTalk
# Opentalk
# Speaky
# iTalki
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# Hello Pal
# Hello Pal
# Speaky
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# Fylp
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# Speaky
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Fylp
# HelloTalk
# Lingbe
# Opentalk
# Hello Pal
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# iTalki
# Fylp
# Hello Pal
# HelloTalk
# HelloTalk
# Bilingua
# Hello Pal
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# iTalki
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Hello Pal
# Bilingua
# Lingbe
# HelloTalk
# HelloTalk
# Bilingua
# Speaky
# HelloTalk
# Fylp
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# iTalki
# HelloTalk
# Lingbe
# Hello Pal
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Hello Pal
# HelloTalk
# Bilingua
# HelloTalk
# Opentalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# Hello Pal
# HelloTalk
# HelloTalk
# Opentalk
# Hello Pal
# HelloTalk
# Speaky
# Bilingua
# iTalki
# HelloTalk
# Lingbe
# Speaky
# HelloTalk
# iTalki
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# Bilingua
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Opentalk
# Opentalk
# Opentalk
# Speaky
# Hello Pal
# Hello Pal
# Lingbe
# Bilingua
# HelloTalk
# Speaky
# iTalki
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Bilingua
# HelloTalk
# Bilingua
# Bilingua
# Hello Pal
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Hello Pal
# Lingbe
# Opentalk
# Speaky
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Bilingua
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Opentalk
# iTalki
# iTalki
# Lingbe
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# iTalki
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Speaky
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Bilingua
# HelloTalk
# Opentalk
# iTalki
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# iTalki
# Fylp
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# Speaky
# Speaky
# Speaky
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# iTalki
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Opentalk
# Bilingua
# HelloTalk
# Lingbe
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# Hello Pal
# Lingbe
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# Opentalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# Bilingua
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Hello Pal
# Fylp
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Hello Pal
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# Lingbe
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# Hello Pal
# Speaky
# iTalki
# Opentalk
# Speaky
# Bilingua
# HelloTalk
# Hello Pal
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# iTalki
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Hello Pal
# HelloTalk
# Speaky
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Hello Pal
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# Lingbe
# HelloTalk
# Hello Pal
# Bilingua
# Bilingua
# Lingbe
# HelloTalk
# Opentalk
# Bilingua
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Fylp
# HelloTalk
# iTalki
# Hello Pal
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# iTalki
# Bilingua
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Fylp
# Bilingua
# Hello Pal
# Speaky
# HelloTalk
# HelloTalk
# Fylp
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Hello Pal
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Hello Pal
# Speaky
# HelloTalk
# Bilingua
# Bilingua
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Bilingua
# HelloTalk
# Opentalk
# Hello Pal
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Hello Pal
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# iTalki
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# HelloTalk
# Opentalk
# Hello Pal
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# iTalki
# iTalki
# Speaky
# Hello Pal
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# Lingbe
# HelloTalk
# HelloTalk
# Speaky
# Lingbe
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Speaky
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Bilingua
# iTalki
# Speaky
# Speaky
# Speaky
# Speaky
# HelloTalk
# Bilingua
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Opentalk
# HelloTalk
# HelloTalk
# Hello Pal
# Lingbe
# Opentalk
# Lingbe
# Lingbe
# Speaky
# iTalki
# HelloTalk
# Hello Pal
# Hello Pal
# HelloTalk
# Opentalk
# iTalki
# HelloTalk
# Hello Pal
# Lingbe
# HelloTalk
# HelloTalk
# Bilingua
# iTalki
# HelloTalk
# HelloTalk
# iTalki
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# Hello Pal
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Lingbe
# Hello Pal
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# iTalki
# Speaky
# Bilingua
# iTalki
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Fylp
# Bilingua
# HelloTalk
# Speaky
# Hello Pal
# iTalki
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Hello Pal
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Hello Pal
# Bilingua
# HelloTalk
# HelloTalk
# Lingbe
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# iTalki
# Speaky
# HelloTalk
# HelloTalk
# Speaky
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# Hello Pal
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# Lingbe
# Speaky
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# Speaky
# Hello Pal
# iTalki
# Speaky
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Hello Pal
# Opentalk
# Hello Pal
# Speaky
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# Bilingua
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Bilingua
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# Speaky
# iTalki
# iTalki
# HelloTalk
# HelloTalk
# Speaky
# Hello Pal
# HelloTalk
# Speaky
# iTalki
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# Fylp
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# iTalki
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# iTalki
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# iTalki
# Lingbe
# HelloTalk
# Hello Pal
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Hello Pal
# Fylp
# HelloTalk
# Speaky
# Hello Pal
# HelloTalk
# Lingbe
# HelloTalk
# iTalki
# HelloTalk
# Bilingua
# Opentalk
# Hello Pal
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Lingbe
# Opentalk
# Speaky
# Opentalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# Hello Pal
# Speaky
# Lingbe
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Bilingua
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Opentalk
# Bilingua
# HelloTalk
# Bilingua
# Lingbe
# Speaky
# Fylp
# HelloTalk
# Speaky
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# iTalki
# HelloTalk
# Speaky
# Bilingua
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# Speaky
# Fylp
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# iTalki
# iTalki
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# iTalki
# iTalki
# HelloTalk
# Hello Pal
# Speaky
# Speaky
# Bilingua
# HelloTalk
# Hello Pal
# Speaky
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# Opentalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# Hello Pal
# Bilingua
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Lingbe
# Lingbe
# Speaky
# Speaky
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# Speaky
# HelloTalk
# Speaky
# Fylp
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Bilingua
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Speaky
# HelloTalk
# HelloTalk
# Speaky
# Opentalk
# iTalki
# HelloTalk
# Hello Pal
# HelloTalk
# Speaky
# Bilingua
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# Hello Pal
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Speaky
# HelloTalk
# Fylp
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Fylp
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Fylp
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Bilingua
# HelloTalk
# Opentalk
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# iTalki
# iTalki
# Opentalk
# Hello Pal
# HelloTalk
# HelloTalk
# Hello Pal
# Opentalk
# Speaky
# Speaky
# HelloTalk
# iTalki
# Speaky
# HelloTalk
# HelloTalk
# Bilingua
# Opentalk
# HelloTalk
# HelloTalk
# Opentalk
# Opentalk
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Lingbe
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# Hello Pal
# Speaky
# HelloTalk
# Opentalk
# Speaky
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# Opentalk
# Speaky
# HelloTalk
# Speaky
# Opentalk
# Speaky
# HelloTalk
# Lingbe
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Opentalk
# Bilingua
# Opentalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Opentalk
# Hello Pal
# HelloTalk
# Speaky
# HelloTalk
# iTalki
# HelloTalk
# Hello Pal
# Bilingua
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Lingbe
# HelloTalk
# Bilingua
# Hello Pal
# HelloTalk
# iTalki
# HelloTalk
# Hello Pal
# Lingbe
# Speaky
# HelloTalk
# Opentalk
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# Lingbe
# Fylp
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Fylp
# iTalki
# Speaky
# HelloTalk
# Speaky
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Bilingua
# Hello Pal
# Speaky
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# Hello Pal
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# HelloTalk
# Lingbe
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# Speaky
# HelloTalk
# Speaky
# Hello Pal
# iTalki
# Opentalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Bilingua
# Opentalk
# HelloTalk
# iTalki
# Lingbe
# Bilingua
# Speaky
# Fylp
# HelloTalk
# Speaky
# HelloTalk
# Lingbe
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# Hello Pal
# Hello Pal
# Speaky
# Speaky
# HelloTalk
# Lingbe
# Hello Pal
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# Bilingua
# Hello Pal
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# iTalki
# Speaky
# Bilingua
# iTalki
# Opentalk
# Bilingua
# Speaky
# Speaky
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# iTalki
# Opentalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# iTalki
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# HelloTalk
# Fylp
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# Lingbe
# iTalki
# Opentalk
# Speaky
# HelloTalk
# Bilingua
# Lingbe
# Speaky
# Speaky
# HelloTalk
# Hello Pal
# HelloTalk
# Speaky
# iTalki
# iTalki
# Speaky
# HelloTalk
# HelloTalk
# Opentalk
# HelloTalk
# Speaky
# HelloTalk
# Hello Pal
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Lingbe
# HelloTalk
# iTalki
# HelloTalk
# Opentalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# Speaky
# Speaky
# Bilingua
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Lingbe
# HelloTalk
# Bilingua
# HelloTalk
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# iTalki
# Bilingua
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# iTalki
# HelloTalk
# Speaky
# HelloTalk
# iTalki
# HelloTalk
# Hello Pal
# HelloTalk
# Hello Pal
# HelloTalk
# HelloTalk
# Bilingua
# HelloTalk
# Bilingua
# HelloTalk
# Opentalk
# HelloTalk
# Fylp
# HelloTalk
# Hello Pal
# HelloTalk
# Hello Pal
# iTalki
# HelloTalk
# HelloTalk
# HelloTalk
# Hello Pal
# HelloTalk
# Speaky
# HelloTalk
# HelloTalk
# HelloTalk
# HelloTalk
# Fylp
# HelloTalk
# HelloTalk

# %%
master = pd.read_excel("EN.xlsx")

# stitch together all the files
for lang in languages:
    print master.shape
    filename = lang + ".xlsx"
    new_file = pd.read_excel(filename)
    new_cols = {x: y for x, y in zip(new_file.columns, master.columns)}
    master = master.append(new_file.rename(columns=new_cols))
    
# split into iOS and Android
is_android = master.iloc[:,30] == "Android"
is_ios = master.iloc[:,30] != "Android"
df_android = master[is_android]
df_ios = master[is_ios]

df_android.to_excel("df_android.xlsx", index = False)
df_ios.to_excel("df_ios.xlsx", index = False)
master.to_excel("df_concatenated.xlsx", index = False)

print "Total Android Size:" + str(df_android.shape)
print "Total iOS Size:" + str(df_ios.shape)
# Out:
# (27265, 34)
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-158-42b8f79f65e8> in <module>()
#       5     print master.shape
#       6     filename = lang + ".xlsx"
# ----> 7     new_file = pd.read_excel(filename)
#       8     new_cols = {x: y for x, y in zip(new_file.columns, master.columns)}
#       9     master = master.append(new_file.rename(columns=new_cols))
#
# /Users/alexcyphus/opt/anaconda2/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /Users/alexcyphus/opt/anaconda2/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /Users/alexcyphus/opt/anaconda2/lib/python2.7/site-packages/pandas/io/excel.pyc in read_excel(io, sheet_name, header, names, index_col, parse_cols, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     348
#     349     if not isinstance(io, ExcelFile):
# --> 350         io = ExcelFile(io, engine=engine)
#     351
#     352     return io.parse(
#
# /Users/alexcyphus/opt/anaconda2/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, engine)
#     651         self._io = _stringify_path(io)
#     652
# --> 653         self._reader = self._engines[engine](self._io)
#     654
#     655     def __fspath__(self):
#
# /Users/alexcyphus/opt/anaconda2/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, filepath_or_buffer)
#     422             self.book = xlrd.open_workbook(file_contents=data)
#     423         elif isinstance(filepath_or_buffer, compat.string_types):
# --> 424             self.book = xlrd.open_workbook(filepath_or_buffer)
#     425         else:
#     426             raise ValueError('Must explicitly set engine if not passing in'
#
# /Users/alexcyphus/opt/anaconda2/lib/python2.7/site-packages/xlrd/__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# IOError: [Errno 2] No such file or directory: 'EN.xlsx'

# %%
# run analyse function on each language with built in print function 
languages = ["EN","DE","ES","FR","IT","JP","KO","PT","RU","ZHS","ZHT"]
for lang in languages:
    analyse(lang)
    print_results("language")

# %%
# run analyse function on device_type
devices = ["df_android", "df_ios"]
for device in devices:
    print_results("device")
    reset_values()
    analyse(device)
