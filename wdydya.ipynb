# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", 50, "display.max_columns", None)

# %%
# Declare all global variables as a class and reset them
# This is so we don't have to globally declare the variables in every function

languages = ["EN","DE","ES","FR","IT","JP","KO","PT","RU","ZHS","ZHT"]

def reset_values(): 
    class glb:
        convo_undeveloped, not_expected, scammers, no_partner, no_help = 0, 0, 0, 0, 0
        messages_not_delivered, photos_not_delivered, audio_not_play, crashed, interpals, other_app, all_android, all_ios, lang_total = 0, 0, 0, 0,0, 0, 0, 0, 0
        technical_ios, too_much_space, too_much_space_android, too_much_space_ios, drains_battery = 0, 0, 0, 0, 0
        drains_battery_android, drains_battery_ios, push_notifications, push_notifications_android, push_notifications_ios = 0, 0, 0, 0, 0
        confusing, not_learning, no_time, change_profile, new_account  = 0, 0, 0, 0, 0
        beginner, dating, no_pay, different_app, hellotalk = 0, 0, 0, 0, 0
        speaky, fylp, italki, opentalk, lingbe = 0, 0, 0, 0, 0
        bilingua, hellopal, duolingo, fylp , ablo = 0, 0, 0, 0, 0
        other_reason, no_notifications, orderless_messages, audio_send_fail, audio_video_quality, other_technical = 0, 0, 0, 0, 0, 0
        too_many_msgs, too_many_calls, offended, technical, technical_android, one_lang = 0, 0, 0, 0, 0, 0
    
class glb:
    convo_undeveloped, not_expected, scammers, no_partner, no_help = 0, 0, 0, 0, 0
    messages_not_delivered, photos_not_delivered, audio_not_play, crashed, interpals, other_app, all_android, all_ios, lang_total = 0, 0, 0, 0,0, 0, 0, 0, 0
    technical_ios, too_much_space, too_much_space_android, too_much_space_ios, drains_battery = 0, 0, 0, 0, 0
    drains_battery_android, drains_battery_ios, push_notifications, push_notifications_android, push_notifications_ios = 0, 0, 0, 0, 0
    confusing, not_learning, no_time, change_profile, new_account  = 0, 0, 0, 0, 0
    beginner, dating, no_pay, different_app, hellotalk = 0, 0, 0, 0, 0
    speaky, fylp, italki, opentalk, lingbe = 0, 0, 0, 0, 0
    bilingua, hellopal, duolingo, fylp , ablo = 0, 0, 0, 0, 0
    other_reason, no_notifications, orderless_messages, audio_send_fail, audio_video_quality, other_technical = 0, 0, 0, 0, 0, 0
    too_many_msgs, too_many_calls, offended, technical, technical_android, one_lang = 0, 0, 0, 0, 0, 0
    
np.seterr(divide='ignore')
    
def print_results(specific="none"):

    # if analyzing languages one by one
    if specific == "device":
        print "----------" + device + "----------"
    if specific == "language":
        print "----------" + lang + "----------"
    print "-"
    print "Mainly one language: " + str(glb.one_lang)
    print "Didn't develop into meaningful convo: " + str(glb.convo_undeveloped)
    print "The app is not what I expected: " + str(glb.not_expected)
    print "There were too many scammers // fake profiles: " + str(glb.scammers)
    print "I couldn't find anyone to talk to: " + str(glb.no_partner)
    print "The app didn't help me much with my language learning: " + str(glb.no_help)
    print "I received too many messages on Tandem: " + str(glb.too_many_msgs)
    print "I received too many calls on Tandem that I didn't want to take: " + str(glb.too_many_calls)
    print "Someone offended or annoyed me: " + str(glb.offended)
    print "I had technical problems using the app: " + str(glb.technical) + ":Android: " + str(glb.technical_android) + " // " + str(float(glb.technical_android)/glb.all_android * 100) + "% :"  + "iOS: " + str(glb.technical_ios) + " // " + str(float(glb.technical_ios)/glb.all_ios * 100) + "%"
    print "Takes too much space: " + str(glb.too_much_space) + ":Android: " + str(glb.too_much_space_android) + " // " + str(float(glb.too_much_space_android)/glb.all_android * 100) + "%:" + "iOS: " + str(glb.drains_battery_ios) + " // " + str(float(glb.drains_battery_ios)/glb.all_ios * 100) + "%"
    print "App drains battery: " + str(glb.drains_battery) + ":Android: " + str(glb.drains_battery_android) + " // " + str(float(glb.drains_battery_android)/glb.all_android * 100) + "%:" + "iOS: " + str(glb.drains_battery_ios) + " // " + str(float(glb.drains_battery_ios)/glb.all_ios * 100) + "%"
    print "Too many push notifications: " + str(glb.push_notifications) + ":Android: " + str(glb.push_notifications_android) + " // " + str(float(glb.push_notifications_android)/glb.all_android * 100) + "%"+":iOS: " + str(glb.push_notifications_ios) + " // " + str(float(glb.push_notifications_ios)/glb.all_ios * 100) + "%"
    print "The app was confusing: " + str(glb.confusing)
    print "Not currently learning a lang: " + str(glb.not_learning)
    print "Don't have time: " + str(glb.no_time)
    print "Want to change profile info: " + str(glb.change_profile)
    print "Want to start a new account: " + str(glb.new_account)
    print "I am still a beginner: " + str(glb.beginner)
    print "It felt like a dating app: " + str(glb.dating)
    print "Didn't want to pay for pro: " + str(glb.no_pay)
    print "Using a different app: " + str(glb.different_app)
    print "Other: " + str(glb.other_reason)
    print "-"
    print "HelloTalk: " + str(glb.hellotalk)
    print "Speaky: " + str(glb.speaky)
    print "Fylp: " + str(glb.fylp)
    print "iTalki: " + str(glb.italki)
    print "OpenTalk: " + str(glb.opentalk)
    print "Lingebe: " + str(glb.lingbe)
    print "Bilingua: " + str(glb.bilingua)
    print "HelloPal: " + str(glb.hellopal)
    print "Duolingo: " + str(glb.duolingo)
    print "Ablo: " + str(glb.ablo)
    print "InterPals: " + str(glb.interpals)
    print "Other app: " + str(glb.other_app + 1)
    print "----- Technical ----"
    print "Some messages not delivered: " + str(glb.messages_not_delivered)
    print "Some photos not delivered: " + str(glb.photos_not_delivered)
    print "Audio messages wouldn't play: " + str(glb.audio_not_play)
    print "The app froze or crashed: " + str(glb.crashed)
    print "I didn't receive notifications: " + str(glb.no_notifications)
    print "Messages or chats were out of order: " + str(glb.orderless_messages)
    print "Audio messages failed to send: " + str(glb.audio_send_fail)
    print "Audio or video quality was really bad: " + str(glb.audio_video_quality)
    print "Other technical problem: " + str(glb.other_technical)
    print "Total: " + str(glb.lang_total)
    print "Android: " + str(glb.all_android)
    print "iOS: " + str(glb.all_ios)

# %%
def analyse(dataframe):

    #Read and split file into Android + iOS
    filename = dataframe + ".xlsx"
    df = pd.read_excel(filename)

    is_android = df.iloc[:,36] == "Android"
    df_android = df[is_android]

    is_ios = df.iloc[:,36] != "Android"
    df_ios = df[is_ios]

    # Count number of device specific responses
    glb.all_android += df_android["#"].count()
    glb.all_ios += df_ios["#"].count()
    glb.lang_total += df["#"].count()
    
    # Counting specific entries for entire dataframe (for this language)

    # 1 My conversations on Tandem rarely developed into a meaningful conversation
    b = df.iloc[:, 1]
    glb.convo_undeveloped += b.count()

    # 2 The app is not what I expected
    c = df.iloc[:, 2]
    glb.not_expected += c.count()

    # 3 There were too many scammers and fake profiles
    d = df.iloc[:,3]
    glb.scammers += d.count()

    # 4 I couldn't find anyone to talk to
    e = df.iloc[:,4]
    glb.no_partner += e.count()

    # 5 The app didn't help me much with my language learning
    f = df.iloc[:,5]
    glb.no_help += f.count()

    # 6 I received too many messages on Tandem
    g = df.iloc[:,6]
    glb.too_many_msgs += g.count()

    # 7 I received too many calls on Tandem that I didn't want to take
    h = df.iloc[:,7]
    glb.too_many_calls += h.count()

    # 8 Someone offended or annoyed me
    i = df.iloc[:,8]
    glb.offended += i.count()

    # 9 I had technical problems using the app

    # Total across iOS + Android
    j = df.iloc[:,9]
    glb.technical += j.count()

    # Seperated by iOS and Android
    j_android = df_android.iloc[:,9]
    glb.technical_android += j_android.count()
    j_ios = df_ios.iloc[:,9]
    glb.technical_ios += j_ios.count()

    # 10 The app takes too much space on my device

    # Total across iOS + Android
    k = df.iloc[:,10]
    glb.too_much_space += k.count()

    # Seperated by iOS and Android
    k_android = df_android.iloc[:,10]
    glb.too_much_space_android += k_android.count()
    k_ios = df_ios.iloc[:,10]
    glb.too_much_space_ios += k_ios.count()

    # 11 The app drains my battery

    # Total across iOS + Android
    l = df.iloc[:,11]
    glb.drains_battery += l.count()

    # Seperated by iOS and Android
    l_android = df_android.iloc[:,11]
    glb.drains_battery_android += l_android.count()
    l_ios = df_ios.iloc[:,11]
    glb.drains_battery_ios += l_ios.count()

    # 12 The app sent me too many push notifications, it got annoying

    # Total across iOS + Android
    m = df.iloc[:,12]
    glb.push_notifications += m.count()

    # Seperated by iOS and Android
    m_android = df_android.iloc[:,12]
    glb.push_notifications_android += m_android.count()
    m_ios = df_ios.iloc[:,12]
    glb.push_notifications_ios += m_ios.count()

    # 13 The app was confusing, I didn't understand how to use it
    n = df.iloc[:,13]
    glb.confusing += n.count()

    # 14 I'm not learning a language anymore
    o = df.iloc[:,14]
    glb.not_learning += o.count()

    # 15 I don't have enough time for the app
    p = df.iloc[:,15]
    glb.no_time += p.count()

    # 16 I want to change my profile information
    q = df.iloc[:,16]
    glb.change_profile += q.count()

    # 17 I want to start a new account
    r = df.iloc[:,17]
    glb.new_account += r.count()

    # 18 I'm a beginner and don't speak well enough yet to have a proper language exchange
    s = df.iloc[:,18]
    glb.beginner += s.count()

    # 19 It felt like a dating app
    t = df.iloc[:,19]
    glb.dating += t.count()

    # 20 I don't want to pay for Tandem and the free features are not enough for me
    u = df.iloc[:,20]
    glb.no_pay += u.count()

    # 21 I'm using a different app instead of Tandem
    v = df.iloc[:,21]
    glb.different_app += v.count()

    # 22 My conversations were almost exclusively in one language
    w = df.iloc[:,22]
    glb.one_lang += w.count()

    # 23 Other (reason)
    x = df.iloc[:,23]
    glb.other_reason += x.count()

    # * 24 You mentioned that you're using a different app instead of Tandem. Which app are you using?
    y = df.iloc[:,24]

    glb.hellotalk += y[(y == "HelloTalk") == True].count()
    glb.speaky += y[(y == "Speaky") == True].count()
    glb.fylp += y[(y == "Fylp") == True].count()
    glb.italki += y[(y == "iTalki") == True].count()
    glb.opentalk += y[(y == "Opentalk") == True].count()
    glb.lingbe += y[(y == "Lingbe") == True].count()
    glb.bilingua += y[(y == "Bilingua") == True].count()
    glb.hellopal += y[(y == "Hello Pal") == True].count()
    glb.duolingo += y[(y == "Duolingo") == True].count()
    glb.ablo += y[(y == "Ablo") == True].count()
    glb.interpals += y[(y == "InterPals") == True].count()

    # 25 Other (app)
    z = df.iloc[:,25]
    glb.other_app += z.count()

    # 26 Some of the messages that I sent weren’t delivered
    aa = df.iloc[:,26]
    glb.messages_not_delivered += aa.count()

    # 27 Some of the photos that I sent weren’t delivered
    ab = df.iloc[:,27]
    glb.photos_not_delivered += ab.count()

    # 28 I couldn’t play audio messages that my partners had sent to me
    ac = df.iloc[:,28]
    glb.audio_not_play += ac.count()

    # 29 The app frequently crashed or froze
    ad = df.iloc[:,29]
    glb.crashed += ad.count()

    # 30 I didn’t get notifications for new messages or chats
    ae = df.iloc[:,30]
    glb.no_notifications += ae.count()

    # 31 My messages or chats were out of order
    af = df.iloc[:,31]
    glb.orderless_messages += af.count()

    # 32 I couldn’t send audio messages to my partners
    ag = df.iloc[:,32]
    glb.audio_send_fail += ag.count()

    # 33 The video or audio call quality was really bad
    ah = df.iloc[:,33]
    glb.audio_video_quality += ah.count()

    # Other technical problem
    ai = df.iloc[:,34]
    glb.other_technical += ai.count()

    # Print total entries in dataframe
    print "Total " + str(dataframe) + ": " + str(df["#"].count())

# %%
# loop through 11 needed dataframes. Throw up specific error if one is missing.
reset_values()

# analyze all languages together
for lang in languages:
    analyse(lang)

print_results("none")
reset_values()
# Out:
# Total EN: 29796
# Total DE: 3404
# Total ES: 14351
# Total FR: 4341
# Total IT: 2721
# Total JP: 4003
# Total KO: 5607
# Total PT: 10706
# Total RU: 9165
# Total ZHS: 3918
# Total ZHT: 373
# -
# Mainly one language: 2710
# Didn't develop into meaningful convo: 9713
# The app is not what I expected: 8429
# There were too many scammers // fake profiles: 3380
# I couldn't find anyone to talk to: 12018
# The app didn't help me much with my language learning: 6895
# I received too many messages on Tandem: 3061
# I received too many calls on Tandem that I didn't want to take: 1526
# Someone offended or annoyed me: 2759
# I had technical problems using the app: 1840:Android: 1086 // 2.08421295052% :iOS: 754 // 2.07833733014%
# Takes too much space: 3520:Android: 2210 // 4.24135416267%:iOS: 1104 // 3.04308277516%
# App drains battery: 2575:Android: 1471 // 2.82309139063%:iOS: 1104 // 3.04308277516%
# Too many push notifications: 1767:Android: 1074 // 2.06118297317%:iOS: 693 // 1.91019598115%
# The app was confusing: 2597
# Not currently learning a lang: 5186
# Don't have time: 17927
# Want to change profile info: 2934
# Want to start a new account: 8065
# I am still a beginner: 6782
# It felt like a dating app: 8900
# Didn't want to pay for pro: 4843
# Using a different app: 2702
# Other: 3427
# -
# HelloTalk: 940
# Speaky: 186
# Fylp: 69
# iTalki: 104
# OpenTalk: 62
# Lingebe: 50
# Bilingua: 70
# HelloPal: 74
# Duolingo: 682
# Ablo: 109
# InterPals: 75
# Other app: 282
# ----- Technical ----
# Some messages not delivered: 419
# Some photos not delivered: 240
# Audio messages wouldn't play: 163
# The app froze or crashed: 586
# I didn't receive notifications: 351
# Messages or chats were out of order: 290
# Audio messages failed to send: 175
# Audio or video quality was really bad: 194
# Other technical problem: 193
# Total: 88385
# Android: 52106
# iOS: 36279

# %%
# get "Other" answers
languages = ["EN","DE","ES","FR","IT","JP","KO","PT","RU","ZHS","ZHT"]

for lang in languages:
    filename = lang + ".xlsx"
    df = pd.read_excel(filename)
    other = df.iloc[:,23]
    for item in other:
        item = unicode(item)
        if item != "nan":
            print item
# Out:
# Джммап
# Changing my device
# I’m so sorry to delete this app because of my full storage
# None
# This application is not good in terms of privacy . I can not delete my chats
# Ghgh
# I wanted to cancel my subscription but the web page didn’t allow it
# ㅈㄴ
# only want
# Many fake people
# j
# Perverts
# Uuuu
# Other
# Other
# Tengo que estudiar un poco más, volveré a hacerme un perfil dentro de poco 😁
# no time
# only want
# Jj
# i dont want say that
# I want to create another account
# this app became like tinder wtf
# Texting with strangers is a little stressful for me
# I do t have time
# Other
# Idhehehe
# already found someone to talk to. thanks!
# It’s boring
# 我想找到之前的好友，我有他的昵称，可是无法找到他。因为...搜索好友只在我的范围内搜，不能直接全网搜
# I didn't realize it cost. And I can't afford it.
# It’s connected to my Facebook account and I have deleted Facebook. I can not access my account without Facebook. There is no option to change this or contact any staff on the app?
# a
# Yes
# h
# 😶
# .
# I don’t want to anymore
# References don't get removed even if u block that partner
# I think the app felt more like a dating app , people contact you by your photo and ask you where are you from, just to start a conversation, and you tell your country probably mostly are not here for language purpose they disappear if they don't fancy your location,I was here to interact with someone for my Italian language learning so this wasn't actually practical for me ... But it's no doubt a good platform for people who like to know eachother ,good work on your team's end 🙏
# dislike
# I'm not good enough
# I need to study for exams for a while
# Bored
# d
# No reason
# Tandem too many issues on iphone 7 plus
# ..
# g
# Good
# personal reasons
# Nnn
# I have less time now
# .
# M.
# Costs
# Hhhhhhhj
# l
# This is too addictive for me
# .
# boring
# N
# Hsjjf
# Want to meet people in person near me.
# I’ve found good friend
# No want reply my message
# Change e-mail
# yea
# It didn't feel authentic enough
# Bnn
# someone pretended to be me
# ...
# V
# Find friend to practice
# I will be back
# Dfetrfffrd
# Not many people to talk to in the language I want to practice
# No way to block men, 100% my messages were men. No way to select the Arabic Dialect, the local dialects from county to country vary considerably so there should be an option to select the country.
# A
# Time
# N
# Too busy but good app!
# Not for me
# Uncertainty about authenticity of profiles and intentions.
# Delete this app
# H
# There is unrespectful men
# Hh
# Buky
# I don’t want this app
# Just checking out the features
# May be some other time.
# Other
# Finished
# No
# Will setup again
# Nobody talks to me
# I lack the free time to use it
# M...
# .
# Other
# Nothinf
# Ghjj
# Hhj
# I already have another account
# I'm busy
# No
# Don't have time to handle it
# Me and my boyfriend decided to delete all the talking and socialapps
# I will be back sometime later
# As soon as I started, a bunch of men just started texting. Felt like a dating app and freaked me out that they knew my location. I do not like that we have to share pictures and locations.
# I don’t like it
# i changed my mind :)
# Storage is low
# I have another account
# ..
# Other problem
# No time
# gyyt hfr
# A
# Jhff
# I don’t have much time to use this app
# Making new account
# ممم
# I dont want anymore. I couldn't find what i expected so im not want use the app. Thanx for all.
# .
# I'm not ready for it
# I dont have time to use tandem right now, And need a break. But if I don’t delete my account I still get connections and emails. (Please implement a pause function for accounts. )
# I dont like it
# Qayıdacam
# Thank you
# I want to start anew
# Cook fyi
# I didn't find anyone to talk
# İ dont like
# I don’t need it
# Gu kg frjbcyikl
# I got tired then bored. Nothing wrong with the app
# Nnnnn
# .
# I cAn’t chang my location but i will back.
# goodbye
# No one responded.
# I m done
# Não quero mais
# Busyness
# Tandem is the best app ever.But I have no time.Thank you very much
# I just want to delete
# I won’t use the iPad
# Ghhi
# Too distracting
# Had a bad reference
# Personal
# I found it overwhelming, my issues not yours!
# Hi
# Nikk
# D
# Need a break from social media
# i’m not using anymore
# .
# It's like a dating app, so I couldn't find anyone to talk. There are few girls, and boys don't reply your messages
# I found a friend
# I want focus school
# Good
# 没有实名认证有很多骗子
# I have another account
# Not interested anymore
# Fjg
# The app is bad and slow, hellotalk better than it
# A lot of racist
# I dont know, just wanna try and make another one
# I have exams
# ...
# Maybe can learn now
# Just don’t want it anymore.
# ...
# ....
# 개인정보 우려
# Gff
# I paid automatically but don’t know paid account is where and what very unhappy with paid procedure
# Couldn't get the encouragement to talk with the other person
# Whenever I tried calling a person from China, we could never actually hear eachother. I'm assuming it's due to a governmental restriction over there.
# .
# Meh
# I don't want to use it anymore
# Too busy
# I just don’t want to use it now, maybe sometime later...Thank u for the good app.
# For not deleting the reference someone else wrote to me
# Social media is bad
# Bj
# People were so unkind, and nobody bothered to reply to my texts. Absolutely horrible.
# A.
# Na
# .
# Need upgrade for looking for friends nearby me
# .
# Other
# There are too many Shincheonji cult recruiters. But Tandem doesn't care at all
# Confusing platform
# Huhgj
# Im too shy, lol.
# G
# G
# .
# I need a break
# Begenmedim
# Gyg
# Didn't got any response
# Hugh jackman you have to be to work at the same time
# Other
# Pay to use
# Busy with school
# Nothing. Iam so sorry
# Dontlikeit
# K
# j
# Lol
# No reason
# I protest social media apps. You cannot decide to that who I am.
# Want a break
# Lalla
# Hh
# For just
# Hhh
# Jwzjekmzkwmxkskx
# I
# Nada
# Hhah
# I hate that i can only change my name once!
# I will come back soon
# Time
# H
# I don’t have time.
# .
# I don't have enough time
# Т
# No comments
# Money
# I have some reason
# I have afraid of my informations
# Ders çalışmak için. Bir kaç ay sonra tekrar yükleyeceğim
# H
# I wanted to change my bio
# No one answer
# Other
# im fucked up
# Im just want to delete my account
# I have my another account
# Tired of app
# Nothing
# Nothing
# Porque nao me senti segura, com as minha informações.
# Need to put real face picture making me feel uncomfortable when i dont use the app anymore and have feeling that people can search me :((
# Delete
# just want to
# Hsvsjabanajbz
# I no longer want to use the app
# Blabla
# i don't wanna use this anymore.
# '-
# Secret
# Nothing
# Too many creeps texted me as a dating app
# I am not learning German anymore
# İ ll come back. İ love this application. Thank you guys. Great work......see you laterr
# Others
# I was spending a lot of time in this app which is not healthy for me :D
# .
# There re lots of man who want to flirt
# Too busy
# Tttt
# I am decreasing my social media presence
# Delete
# Wrong
# I’ve had this app a long time and I’ve made enough connections to keep practicing languages.
# Other
# Curios if its fake account
# im tired too much for this
# h
# Bullshit
# Busy with school
# I don't wanna use
# I dont have time for this app
# I don't need to use this app anymore, thank you
# No time
# Time
# He
# I want to be focus on my study at school. So, i will not get distracted by learning from tandem.
# I’m spending a lot of time here
# You work money-focused so that I can talk to someone with the qualities I am looking for about language.
# hjm
# Ghn
# I just need a break
# İ dont want
# You deleted all my messages!
# See
# Nvm
# Borred
# Tgv
# Fgg
# Nothing
# Because I want
# Saya terlalu malu untuk memulai percakapan
# Delete
# Xxx
# ..
# Too much flirting 😂
# Sorry
# w
# I want use it on my cell but the account can not connect.
# No possibility to identify the search for Portuguese from Portugal instead of Brasil.
# .
# Nobody is interested in talking to me
# Other
# Vdbbdbd
# Nothing
# H
# Ln
# I just don't use it.
# I'm just bored
# I rarely have time to play it.
# There are so many “romance scams and fraudsters” in this app. Company should pay more attention on this problem.
# Lo
# I just want to, but it’s a good app tho
# Not interested anymore.
# This app is slow
# i started going to english classes in person.
# Price
# Nothing
# H
# Hh
# I like
# Changing my device
# To many commercial
# It is difficult to make friends. You must have the courage to chat them first. I think it would be better if there's a part wherein anyone can post. That will help users or learners to find their learning buddy or a friend that may help them.
# Me agobiéh
# I didn't want to use this site any more
# i’m done
# This App is used as a dating App disgusting
# hşgxpycşhcşgclgc
# Found a language partner in real life
# No people talked to me
# No one wants to practice. They always exchange a couple of phrases and then won’t talk to you ever.
# I’m not really interested anymore
# I can’t edit my profile so I want to make a new one
# my phone ran out of storage
# ㅡㅡ
# I
# Not a great variety of people to sepan to.
# .
# Njkk
# Xyz
# Other
# I can't suspend the fact that I am unavailable to help, or not looking for help at this time. Rather then answering everyone adding me I'll just delete my account. I didn't want to ignore requests and offers i usually acknowledge people
# No reason
# bye
# I feel like only think that motivates people is the thought to find a relationship, not learning the language, second think is about the problem I already mentioned to tandem community.
# Every man just talk about sex
# Χ
# .....
# Fi fi
# .
# The app randomly lost all my convos of people I was talking to and I couldn’t find them via search
# Hgh
# Blah
# just bored
# It's more like one sided conversation.
# just because I want
# I'm just taking a break
# Just taking a break for now
# I don't want people to follow my profile without my consent.
# I didnt get it
# i'm too busy
# No one wanted to talk to me
# Hj
# ㅇㅇㅇ
# I’m always logged out, maybe creating a new profile will fix this problem
# Other
# There are too many fake profiles and I hope the profiles are being examined prior to approval of the application
# А
# knbvvvc
# ok
# Ok..na
# Great app will definitely come back but right now I need to rest from it
# Personal discomfort being approached by male users
# H
# I am bored
# Something went wrong.
# I haven't enough time to use this app
# I want to start over.
# I will download again later
# Está muy caro para lo que es
# I received treath from someone
# 11
# I cant change my name.
# Just needed a change
# They didn't want to chat with me
# None
# Underage
# Jsnsnsns
# Changed my mind
# I chose a free course, but it charged a lot of money.
# Other
# I don't wanna more
# I had another Tandem account and
# I don't want to use
# Other
# Changed email
# No
# Had a great time and learned a lot of korean and made new friends. Don’t need app anymore
# Many bugs are there in this app
# W I don't know
# I have two accounts
# I have a different account
# I not like it
# It's my fault, i did not put the right information aboit my age
# Concerned about privacy
# Temporarily
# H
# No one interested me
# Social anxiety
# Jsjsjs
# Everyone who messaged me at first was the opposite gender, and they all said things like "hello beautiful". No offense, but I am married and only wanted to learn a new language, not sign up for an international dating app.
# Delete
# l
# I just want to go
# nada
# .
# I’m very busy with other things right now
# Tandem appears deceitful about how to cancel free trial and makes it difficult to know how to stop my account from being charged.
# Personal issues
# I had profile with jackbauer1414@me.com , I can’t Acess that profile any more
# No comment
# Not happy
# I like not it
# Assf
# W
# no one wants to be friends with me
# Anything else
# Kkkac vgnhmez
# I can’t access to the account I already had
# Nzzn
# Nothing
# I need a nice photo for european and russian girls to talk to me
# No quiero seguir usándola
# Hj
# L
# Wanted to meet in person but no ones around
# .
# I not have time
# ......m
# .
# Other
# I'm moving to Russia thanks to tandem, I don't need it anymore. I'm very grateful for tandem community :)
# Hahah
# '-
# Bored
# I want to make a new account
# I
# I was scared that so many old people were checking out my profile ...I don't want people to see my face . The required request was the only thing that was bothering me
# Rfghjfdt
# no reason
# I want
# I had no conversation, No ones was chatting with me even though I started the chat
# I want start a new account
# Aea
# I can't put my profile in private mode to limit request from people I don't want.
# Nbb
# Nobody answers on my massage
# .....
# Slow net
# I will joint later
# I really like this app
# i dont like
# people are weird here
# Hdbbdbd
# I found a friend to practice with and we moved to a messenger, which is more comfortable to use
# Secret
# I don’t use it anymore
# Bored
# I am busy
# I just want to
# I'm antisocial
# Just dont want it
# Na
# Didn’t enjoy talking to people I didn’t know
# I am trying to find me. Wish me luck please❤
# My ex was in here
# hhhh
# Ddss
# Kind of took the joy out of languages a bit.
# Tae
# Seems like most are there for dating and not learning
# I met a scammer on the app who asked for my WhatsApp number and started trying to get money from me so now I’m scared
# I am underage
# Bored
# I meet someone
# I didnt need that anymore
# Hahahaha
# Bored
# Nothing
# It gives me anxiety
# I dont like
# 不好玩
# I don’t want anymore.
# Blah
# Bored
# L
# Its nothing
# The app has been of much help, moving on to a new phase where I don't need the app anymore
# Later
# Very good
# Prefer real relations
# Bc y vb
# I dont know
# Great app, dont need it anymore.
# M
# H
# I can’t really talk to someone with the language I want to learn. It means the app is not really professional.
# 想改名字
# I need a break
# Спасибо
# Just bored with it
# None
# I don't like it
# Didn't like it
# .
# Needed a break
# I just needed to see if I was blocked on my other account
# No time
# Não quero usar
# Useless
# I found someone I liked that is helping me With Spanish
# X
# I don't have time
# Hdkdkdk
# Because
# M
# No
# Busy
# Busy
# ，
# many ads
# .
# Gg
# I was locked out of my other account and had to delete this one
# I want creat another account
# Ghu
# Honestly I had a really good time I learned a lot of languages and I just thought it was time for me to go
# no interest
# I am learning korean so I wanted to practice it with native speakers but on Tandem they seem to only want to talk about god and the bibble
# Nah
# It consumed my time
# Nothing
# ...
# I am tired of the application
# I’m not on here much
# No messages
# Jzjzjxkzkxkxllxx
# No thanks
# .
# N
# Meh
# I don’t have time
# I dont like this app
# Test
# No
# Too many people assumed my level was really low and wrote to me as if I were a beginner.
# I'm busy
# Changing my device
# A lot of aggressive people
# ...
# Kho  go vhvhubbbbbhc
# .
# Meh.
# you cant just check too see what its like, you force us to use real names and pictures, i just wanna have a looks then make my decion to put on my profile picture
# Privacy issues
# Nothing
# Some profile pictures were offensive
# Whatever
# Na
# Na
# Ф
# Jsks
# Took away time from learning Target language
# I have a low self esteem so I don't wanna show my face and is really sad that someone really took the time to report my account when it was just a picture from a museum
# Wlay gusto mu chat nako
# Couldn't login via email
# Hhh
# No
# busy
# Nothing
# Vvv
# E
# Hgcchjj
# Im not interested anymore
# I applied as a tutor not a learner
# Fraudulent charge!
# The most important feature "near me / same city" is locked behind paying
# 不能更改头像
# I DON'T WANT TO SHOW MY FACE
# Don’t have time
# Нет времени
# Other
# ...
# The app is so great. But, I want to focus on something for now.
# I'm too busy
# Hhggnbfghbvc
# Got bored
# Nothing
# K
# Y
# I want delete it temporarily
# I’m a bit busy , doesn’t have enough time, will join next time
# It's temporary
# I dont like
# Fghgvh
# A
# T
# I didn't enjoou
# Too much of a novice to talk to people
# I was busy
# Nothing
# j
# Qwerty
# I'm bored
# Nothing.
# I don't see this app necessary.
# men flirting too much
# I just don’t want it anymore
# I am taking a break from social media
# First conversation was asking way too much personal information. Made me uncomfortable
# No time
# חחח
# 1
# No time
# E
# Hate social
# I got in a relationship with a tandem friend we decided to delete the app wish me luck
# No
# .
# aku salah memasukkan data diriku
# Private reason
# dont want
# a
# nothing
# F
# Hdjajdjd
# Hh
# .
# Right now i dont have time to spend it on the app
# i do not willing to use anymore
# Hhjj
# No
# '-
# Oggghgfvvfg
# No
# .
# ,
# . K
# I will study
# gjfybdib
# I dont want
# Ok
# .
# I didn't receive any replies
# i don’t wanna use anymore
# Ghhh
# Exam
# other
# Nope
# Hhkjnh
# The internet is too slow
# I have a different account
# i don't feel like using it anymore
# because i don’t like more
# Nothing
# Boring
# No me gustó
# Fuck you
# A
# Realized I’m not a girl
# Recreate an account
# People never talk with me...I'm feeling alone
# Nothing
# I don't use it anymore
# I have been very busy
# A
# Personal. I'll be back
# No
# My boyfriend was jealous, because men were talking to me... 🤦‍♂️🤦‍♀️
# sdgdtrhygfthjgjtyjhghjtyjhg
# i'm bored
# bylkbgykm
# I don't have time for the app because i am preparing my exam
# I thought I was ready to take my learning to the next level, but I felt daunted by the prospect of having to message strangers to practice. Apologies for any inconvenience.
# Wasn’t using it
# .
# Nothing
# Mmmm
# I decided to choose a few people that could really help me and talk on WhatsApp... all of them I met on Tandem, só the app is really helpful but I don’t have time to get to know more people 😬
# w
# Nothing
# Bb
# Nothing.
# My visitors is deleting
# I was filled wrong about my age😂
# No tengo tiempo para practicar ahora
# i want to create a new account
# Ja
# I got very bored
# Im bored
# I am leaving on a mission, and will not be able to use the app anymore. (Phone and computer use is limited and monitored during that time)
# vj
# I m focusing toward my study so i can get better grades thank you i had a good time here
# I'm cannot change my location
# nothing
# i don’t like
# Other
# I'll back soon
# I have a german person near me who i can talk with
# Jhh
# Im hone
# I’m too busy
# W
# Girlfriend
# Bored
# Bhjk
# adddddddddddddsd
# I not using it
# k
# Meet people make me anxiety
# .
# Gbb
# Have another acount
# .
# Hybnj
# I’m not using it as I should. Need more time
# L
# I will focus on school
# I don't have time
# C
# Personal affairs
# Bored
# No one replied to my messages
# Personal stuff
# Not ready
# I enjoyed being here and I met some new people but everything is only good in first meeting or chat. I never met someone who wants to be a long time language partner. Instead of making myself improve I only learn how to greet and introduce myself.
# I had another account so needed to delete this one
# too many ads
# B
# Other
# Hıdgjfgjh
# Ok
# .
# Making a new acc
# า
# H
# I could find my previous account
# I want to delete my account
# Other
# Hh
# Too expensive
# I don't want use any apply
# Nothing
# Fes
# No reason
# I write a wrong name, and I can’t change that
# Didn't use it
# Boried
# H
# I have a relationship anymore :)
# i dont have friends here
# I dont have free time
# I can't change my profile picture to any picture that i want
# I don't have space on memory
# I already have a account
# I received messages I wouldn't want to receive...
# Hshdh
# Me aburrió
# other
# Imma make a new one lol
# M
# No
# Other
# Other
# Okf
# wck
# Anyone does not want to talk
# Don’t use it anymore
# I made enough friends
# I’dont have time
# A created another acfo
# Because of US sanctions i cannot upgrade to pro
# F
# it's so fun i waste too much time, i will come back
# kk
# ...
# Mmm
# I don't know
# TThe app is wasting my time
# Takes time
# Boring
# I lost my Google account
# I dont like data.
# Most of the good content is on pro
# I don't want to use
# I received a lot of call from anroad
# You guys need to remove the accounts the have inappropriate images.
# Nada especial
# Sadece yeteri kadar ilgi gösteremediğim için gidiyorum. Her şey için çok teşekkür ederim. :)
# .
# Didn’t like having my name and profile picture for everyone to see
# I don't want to use it anymore
# I’m to shy to use it
# Gjjnhhh
# Gg
# felt uncomfortable using a picture with my face
# Other
# Can’t improve
# I don't have a stable internet connection.
# I don't want to show my face!
# Wrong intro
# BFF.
# I don’t want to be prt of the community anymore
# Could not change my tagline on profile
# jsjsjs
# ...
# It's not my cup of tea
# Not write me
# Personal problems
# Yihf 2,fzgg dshs nwh wsu shdbe hdud u
# No one wants to talk to me.
# W
# Stuff
# Couldn’t change my profile picture
# People actually leaves you a lie as a reference if they are psychos
# Just want to delete it
# Eh
# I just want to?!!! App was perfect and I have learned a lot. It's somthing personal. I'm pathetic. That's why I am doing this.
# N
# My little sister created this account without my knowledge, gladly I am 3 language fluent so I’m not interested in learning some more at the time...Thanks
# I used it wrong
# Bnjk
# I do not want to publish my own picture since anyway it is not a dating app to see how I look like. I received a notification that my account was reported for containing a pic not belonging to me. Then there was a warm from tandem that my account will be banned within 24 hrs. If for learning language a pic is a must then I don't need this app. Sorry.
# I'm too introverted.
# .
# A
# I don’t have much time as before
# I didnt use it to be honest
# Just taking a break from languages for a bit. Tandem is an excellent app, which I am sure I will use in the future.
# I joined because I wanted to know what all the languages were. I’m glad to see that you offer Serbian and Syriac, two languages I want to learn and have struggled to find. Now isn’t the best time for me to use this service, but I’ll definitely download it later!
# My memory is full
# Always late reply
# Beacuse I want and this is all
# Just tried this app out of curiosity.
# I dont have time
# Hff
# Kdk
# O
# No quiero
# I don't need
# I used it like a dating app, which is of course against the rules
# No reason
# Didn't like it
# I JUST BORED
# Friends don’t write me
# Nil
# A
# It hard for me to talk because I'm not good English.
# Ok
# .
# Lkkk
# I would like an option to delete my Messages permanently
# '-
# The app is way too strict with its users. Keep going like this and you’ll lose all your users.
# k
# N
# I found my soul partner
# Nothing personal
# Hgcb
# Porque eu não quero mais usar
# I didn't enjoy it.
# türklük
# I don't like this app
# I was busy
# I'll come back here, I love this app
# :)
# Desinstalar do meu celular. Não quero usa lo mais.
# I entered my age incorrectly
# Na
# ok
# .
# I got bored
# not interested
# Busy
# Other
# Ys
# I don't have time
# Suddenly I felt scared of exposing myself, because some ppl use the app to date.
# '-
# G
# BHGV vyvtdtfyvygtctgybihtfrvubyvyvtdtfyvygtctgybihtfrvubyx
# Ghu
# I just didn't feel like wanting it
# Jj
# I think This App not for me
# Boring
# N
# Other
# ...
# I have a language partner
# Personal reasons.
# H
# I don’t have time
# A
# Stupid japanese racist people
# '-
# It's nothing
# A
# No es para mí esta app
# Gkfc
# Thanks
# Seguridad
# No time
# I have another account
# Hmhdkdkslsk
# I learnt the language
# It turns out I'm not smart enough to use this application
# H
# .
# Beauty
# B
# Me han efectuado cobros de 3 veces renovación, solicito la devolución de mi dinero. Es imposible que haya comprado teniendo una suscripción otras 3 suscripciones para el mismo periodo.
# Time
# Your app facilities are old , If you put WhatsApp facilities  on your app ,it will be very good,more better than WhatsApp, because your app has a option of teach to each other and it is big community that we can find new friends .
# Others
# No time
# Yhfiyo8uigydrxfruib
# I just don't  have time.
# Shit
# I realised that I do not trust to talk to strangers
# W
# The people just got weird and suspicious
# Jjjj
# Many men were messaging me in a flirty way
# Geh
# Because I can
# Nothing
# No eespara mi
# G
# Friend told me to download app, didn’t know what is was until I downloaded it.
# Asdf
# My messages weren't replied
# Idk
# '-
# Other
# bye
# Orher
# I can't reset my ID
# I dont say
# I don’t want
# I am busy lately and can’t make enough time for spend on here
# Gg
# Tandem dont show the message that people sent me
# My girlfriend was annoyed about all the girls I was talking to. I tried to talk to guys but only the girls responded
# My account was hacked
# ..
# Hh
# f
# I m bored
# My tandem partner told me I’m annoying 😔
# .
# It just doesn’t make sense, everybody has to chat with English anyway, no special features on the app for any kind of language learning, basically it’s just another dating app for most of the users
# Need a break
# Tired
# Don't have time to use the app
# On
# .
# idk
# Jdjdjd
# I will probably come back eventually, but I’m done for now.
# I can't delete some messages which I sent and want to be removed like other apps
# I don't need this app anymore
# na
# OK
# Ghhg jkgjj
# I don't want to use this app anymore.
# I don't like
# One
# Not yet
# Recreating my account
# I accidentally changed my age to +99 and can't get back to -18, that's made a Turkish man with 32 years old start send messages to me, calling me BABY, and I'm very worried about it, so I'm going to create other account, thanks
# It would be helpful if you could put your account on pause once you had enough conversation partners- I kept getting matches and messages and it was overwhelming so I just stopped after a while
# I'll be back
# N
# This is a duplicate account cause I couldn't log in earlier to my original acct
# No reason
# Its boring
# There are a lot of cheaters, even some people pretending to be astronauts, saying that he is now in space, and he is going to invest in travel in my country in the future, and want to add my wechat
# This isn't a dating app, why do I need a photo of my face in order to practice languages??? My privacy is more important than your arbitrary standards. Perhaps you should consider avatars.
# I don't want it anymore .
# I want to create another account
# No
# I received messages from men who look for flirting
# Special, other
# .
# I'm busy
# I will be back :)
# Nothing
# it takes time
# Tandem delete all dialogs
# Can't change my gender
# У меня есть другой аккаунт
# A
# No reason for leaving.
# I have another account cause tándem don’t let me login and I’m gonna try to use the 1st account I did
# Gaha
# kkhugyuuuuuuuuuuuyyyyyy
# I don't want
# K
# Privacy concerns
# I had account
# Is this dating app? I want to learn not hook up
# .
# Maybe come back
# I got hacked
# Other
# I may come back again soon :)
# Q
# .
# Cant
# No time
# Too many scam accounts.
# Too overwhelming
# A lot of people just want to hook up and I just wanna learn
# I will create another one from scratch
# I will create new account
# I can not to clear fast the old conversations
# Because I want to just delete it
# Busy
# Harassment
# J
# I didn't have the time to spend to learn
# Fghjrykggjkfyjuy
# Nothing
# K
# Jjjk
# gdsgomvdwtub
# .
# I just wanted a new account
# Iam change my phone
# İ didnt have to use account much
# My Tandem inbox is not working .
# رؤيت
# 不喜欢
# I will change my phone, so delete all apps include tandem
# The app knowing my location made me feel bad esoecially because some ppl are creepy
# Sezgin
# Sıkıcı
# 無
# Just didn't like it
# .
# not free. i haven't money
# App is not work in proper way
# Other
# Bla bla
# The app constantly broke down, several times I was logged out without reason. I going to join again but now with my google account instead Facebook.
# Idk
# .
# Tiene muchas fallas la app
# Its very good App .it's my own fault why I am leaving this app because I tried to flirt with some female users and I feel bad that some of them misunderstood my jokes as well ..I will absolutely rethink in the future and see if I can start fresh again .good app and nice community here I love this app designer and Tandem Community
# There aren't many people of my age group. I have decided to take online lessons instead. I think Tandem is fantastic for younger people though.
# .
# Blah
# Alright
# Other reason
# I don’t have enough storage
# No
# Nd
# Jojo
# I got bored
# I don't want to use this app
# Ffffff
# ...
# Just wanna leave
# Didn’t like it
# Using a different app for language learning
# I need rest
# New account
# I do not have time
# Xmmammamamz
# I want delete
# I don't want to do this anymore
# chfyghhbh
# i was blocked by someone and i felt sad, i didnt do anything wrong
# Don't have any text to me
# Too many weirdos
# I just want to delete it
# Ok
# Need to focus about job
# I have found a good language partner here
# I’m too anxious to use the app :(
# I love the app. I just need a time for me. I’ll back in some months.
# :(
# No uso la app
# I think I need to practice more before I can converse
# vu que
# Vv
# W
# Hbbjkl
# No
# Other
# Someone getting into my account
# I was just spending too much time. Otherwise a great app. Thank you
# Privacy
# People think this is a dating app, so annoying
# I want take a rest
# I don't like learn
# it’s a good app, maybe another time I will download again.
# Wasn't old enough and didn't realise
# I have to :(
# it was fun ty
# Hhhhhh
# Got a good level of the language i am learning.
# Gfffffffffffffggdfvrvdccww ecqcwcw w
# Waste of time
# .
# Busy
# I don't want to use
# To much expensive
# Pro is costky
# Not interested
# .
# Too many hot girls messaging me I’m too distracted
# There is no option to delete message history. İt is irritating that you cant delete message permanently
# I just want to take a break
# I don't have time to talk
# I didn’t feel safe with my face and location being shared to strangers.
# Me aburri
# i’m done
# I got no language partners i give up
# İ do not like that app
# Idk
# Nothing
# H
# I didnt like
# Huhjo
# .
# Later i will be in contact with you to tellyou why i deleted my account here     nxndjdjjdjdjxjxjzjznnnznznznznznznnxndjdjjdjdjxjxjzjznnnznznznznznznznznznznznznznzn
# Kinda not interested anymore with this app. And when i chat someone to teach me they only read it. and i thought i was polite enough to start a conversations
# I loved the app so much, though it’s time to go :)
# I don't want
# No
# So many people put adv on it. It’s not a pleasant phenomenon
# Ooo
# I do not have time to learn languages now
# Move to new hand phone
# .
# My free trial has come to end
# None
# why I want just
# Hjbj
# فضولی
# I am stress i am sorry
# ר
# Hssb
# Gapapa
# Nkjjcckk
# Sorry
# Other
# I want to have a vacation from the app, maybe in the future I will open a new account. Thank you. I give 5 /5 stars to the app :)
# I didn't use the app at all.
# Fuck you
# I'm more awkward than I realised
# Woah
# Hjj
# Busy
# H
# I don’t use it anymore
# Hhhhjuiuuu guiiiivc
# I'm ugly and no one wants to talk to me
# There's no option to skip this dumb survey
# Porque eu quis mesmo.
# I don't want to use anymore
# .
# Nil
# N
# Nothing
# Tandem send me too email
# Jj
# I don’t use it
# Nothing
# Nobody talk with me
# Hh
# Bb
# I’m done
# it is just not for me
# Aaaa
# Don't want to pay for it
# Just wanna
# I not have time to use
# altro
# Other
# I dont need it anymore
# Thx
# Jgun
# Fsddgg
# I hate this app
# I am busy
# Goodbye
# Just got bored
# .
# H
# I just don't want it anymore, sorry
# Sbshah
# New account
# I was helping more people. Then more people helping me
# Busy
# I’m just very introverted and scared as hell to talk to other people lol
# .
# J
# Nothing
# .
# change of mind
# Yes
# It's hard to find a pernament language exchanger
# Hi
# Just tired
# I wanted to start over with language exchange since I stopped learning for a few months
# Hdkkdkfkc
# :shrug:
# .
# Expensive
# 有另外的注册号
# I don't have money
# K
# Nothing
# Switching phones, and since I have no access to my email, I’ll create a new account.
# i don't need it any more because i'm fluent
# this app is not confidental
# Hghg
# I early open this application
# I go back later
# 0
# ...
# Ich habe einen festen sprachpartner auf Tandem getroffen, mit dem ich regelmäßig telefoniere. Zu Beginn macht die App den Eindruck einfach nur eine dating App zu sein. Jedoch liegt es an einem selbst, wie man sie nutzt.
# Bla bla bla hshshybybwnwkdnxnfnnx
# Genug Muttersprachler in normalem Umfeld
# E
# Ohne Grund
# Keine
# H
# N
# No
# keine Zeit
# Alles
# .
# Tud mir leid
# ...
# Keine Zeit
# .
# The App just took the picture of my Nephew as profile picture without my concense and the worst is that i couldnt in my pictures it didnt appear in the pictures i uploaded, it could be seen only on the profile view. I have already sent an email too with the screenshots of this problem, I hope I get an answer from your side, because i like the app but to use pictures without concense is not right.
# Verstehe die App nicht
# War ein Test. Komme später vielleicht darauf zurück
# Momentan keine Zeit
# Ffc
# .
# Ich habe genug wundervolle und hilfreiche Tandempartner kennengelernt, mit denen ich nun auf anderen Messaging Apps kommuniziere. Deswegen benötige ich die Tandem App vorerst nicht mehr.
# jgh
# ???
# Hh
# Hh
# Zu wenig Motivation
# ...
# Nnn
# Ich wollte Tandem pro kündigen u d es war nicht ersichtlich wie
# Idkwndkdoenfnd
# Bin eher an direktem Kontakt interessiert, der sich über Tandem nicht ergeben hat wegen zu großer geografischer Distanz
# Khgh
# Too many chinese
# Keine zeit zum chatten
# Ka
# Hh
# Usw
# Chose wrong language
# Es haben mich sofort so viele angeschrieben, dass ich nicht hinterher kam. Bei einigen konnte man nicht sicher sein, dass sie nur Sprachen lernen wollen. Ich fühlte mich unwohl, dass manche sich sofort treffen wollten.
# Hdhdhfhfjgka sjajajw sjdjfjr jajsjs djdjfhd djdufhr
# Ich habe meinen Exfreund hierüber kennengelernt und möchte mit der Erfahrung abschließen, außerdem nimmt die App viel Zeit in Anspruch und ich scheine nicht sonderlich gut darin zu sein meine Sprachkenntnisse zu verbessern(ausgenommen von Englisch).Dennoch hat sie mir viel Spaß bereitet
# ghjjk
# So
# Brjfhd
# Nights
# Die App finde ich nicht ideal
# Nein
# Blabla
# Kein Interesse mehr
# Ich will kein App mehr haben
# W
# Später
# Preis
# Svbkj
# Private Gründe
# Zu wenig leute
# Zh
# Andere
# J
# Sonstiges
# Keine Angaben
# Zu teuer
# Ich habe Tandem fast nie benutzt.
# .
# Ich habe keine Lust zu chatten und würde mich lieber mit Leuten treffen. Schade, dass man zahlen muss, um zu sehen, wer in der Nähe ist.
# Ich habe einfach zu wenig Zeit
# Befasse mich zu wenig damit
# S
# K
# X
# B
# Ich will nicht sagen
# Fghsfg
# Hhggffhhh
# ... .. .
# Ght
# Just because
# 123
# Ich treffe mich lieber live und übe die Sprache
# Ich dachte es wäre kostenlos
# Habe sprachpartner gefunden und Ziele erreicht......
# Hs
# Keine Zeit.
# Jvnblkbvgxxwwbvand
# H
# .
# Kostenlose Testversion anbieten und dann nicht mal sehen können, wer in der Nähe ist?? Danke, aber nein danke.
# ...
# später
# .
# Sinn macht die App nur wenn ich ohne bezahlen Leute in meiner Nähe sehe.
# Hha
# Kein zeit
# Ander
# es wird mehr zum flirten genutzt. es fühlt sich schlecht an, wenn man einfach die Sprache lernen will und dann feststellt dass deine Aufmerksamkeit anders geschätzt wird.
# W
# Kann Leute aus der Nähe nicht treffen ohne zu bezahlen
# Ich habe ein anderes Tandem Konto,in das ich mich aber leider nicht einloggen kann, deshalb habe ich ein neues erstellt.ohne die "alten" Leute ist es aber leider nicht dasselbe. schade
# Hjugh
# Ich habe meine tandem Partner gefunden, danke der community :)
# Knnn
# Meine freundin erlaubt mich nicht
# Mein Konto wurde ohne Grund blockiert
# Gshz
# So halt
# The app upgrade was wrong. I am not allowed to manage the subscriptions due to error messages
# Nix
# Die App hat mir sehr geholfen aber jetzt habe ich viele Möglichkeiten außer der App, mein Deutsch zu üben. Danke!
# vielleicht später
# Hhuhggff  ugff  b yuyf
# Work
# Zu teuer
# Keine Lust
# keine angabe
# shy
# Wollte mir mal eure Korrekturen anschauen aber konnte nichts finden
# Ich lerne mit anderen im echten Leben
# Leider gleicht die App einer Datingplattform
# Ich möchte eine Möglichkeit mein Konto zu deaktivieren. Außerdem möchte ich nach Fremdsprachenkenntnisse filtern können.
# .
# Hhh
# Taking too much of my time
# Meine Freundin wäre Sauer wenn sie sehen würde, das mir nur Frauen schreiben
# Zu teuer
# Mit wenigen Leuten geschrieben
# L
# Ich habe mich nicht wohl gefühlt
# Neu
# Another problem
# Me enamoré
# No me gustó como funciona la aplicación
# W
# No me sentí segura en la aplicación, hay gente que dice ser alguien más y usa fotos falsas.
# Quiero eliminarlo hasta nuevo aviso gracias
# No la uso
# Quiero tener más tiempo para mi
# N
# Otro
# W
# Otros
# .
# V
# No tenía tiempo
# Otro
# Tengo tareas que hacer. Lamento irme volvere. Y no me da tiempo estar en esta app.
# Me enamoré y me dejó
# No quiero
# Quiero reactivar mi cuenta más adelante, pero ahora voy a cambiar de lugar de residencia y con ello mis números.
# no tengo ganas de habalr
# No estoy interesada.
# Nada
# Encontré alguien para realizar intercambio de idiomas y nos comunicamos por otra app
# Akjajaa
# Los mensajes no son cifrados de extremo a extremo. Sé que es para evitar abusos pero deberían tener la opción de eliminar los mensajes para ambas partes y cifrar los mensajes.
# conseguí alguien con quien aprender
# Solo ya no lo necesito
# .
# Other
# Other
# Ya estoy aprendiendo con otra persona
# No deseaba seguir practicando por la app
# No me gusta que no se puedan borrar las imagenes
# Xxx
# Tomaban datos personales
# No
# Solo me hablaban con otra intención
# No quiero seguir
# Ssd
# Nadie se dedica a escribirte.
# Todo bien
# Necesito un descanso
# Espacio en mi teléfono
# Ftkekrorornrnrltt
# 👌
# me aburrió
# No la estaba usando
# Sem tempo
# Solo por qué me use una.cuenta nueva y me va mejor en esa
# Voy a aprender los idiomas de otra manera
# Monki flip
# Laks
# Hay mucho impostor
# jajaja sjs
# U
# No tengo tiempo por ahora
# No se utilizarlo
# Jsjsjds
# Estaba muy enganchado en ma app y no prestaba atención a lo importante
# Te podia hablar quien quisiera sin pasar poder pasar tu un filtro antes
# Simplemente decidí eliminarla
# Quiero tomar un descanso
# J
# No
# no me interesa más
# No estoy teniendo acceso a internet por el momento
# No me interesa ya
# .
# No tengo tiempo
# Otro
# Otro
# Dms
# Voy estar inactiva durante un largo período y no voy a utilizarla por temas personales
# Nada
# Quiero estar menos tiempo en internet y más tiempo con la familia
# Mi prima me dijo que lo borrara para
# Cgnnjn
# Ok
# La gente demora mucho en romper el hielo, y casi nunca hablan. Por lo que la app no me ayuda mucho a mi aprendizaje
# .
# Idk
# Otro
# No lo entiendo
# Personal
# Nada
# Porquesi
# Tuve problemas con varias personas, las denuncie pero no fue suficiente, la aplicación es genial
# B
# K
# M
# Porque si
# Por que distrae
# No tengo tiempo para conversar con otras personas
# Nada en particular
# Si
# Problemas extras
# W
# No me interesa lo suficiente
# Kkjhh
# Me dio pereza
# No es mi tipo de app
# Xxxx
# Software malicioso
# Por gusto
# Ya
# .
# Básicamente es una aplicación de citas pero en otros idiomas. Muchos perfiles falsos
# No lo utilice mucho
# Nomas
# Me robaron el cel
# N
# Nose
# No encontré personas que hablaran el idioma que buscaba
# No había gente cerca
# Me enamore y me rompieron el corazón  :(
# No es para mi
# Necesito un espacio, es temporal
# Por q si
# No tengo mucho tiempo
# Cv
# J
# No tengo tiempo para usarla
# .
# Me quita mucho tiempo
# W
# I have girlfriend now, Tania
# Ya no me ayuda
# X
# la persona que mas me agradaba ha dejado la app
# Nose
# No la uso más
# No me sentía segura
# Ya se me iba a acabar la semana gratis
# Solo ya
# Ir un eldmfbmdkdk
# No ingreso
# Other
# Otra
# Quiero crear otra nueva
# Problemas con las llamadas, mostraba la camara tanto mía como la del usuario  con quien hablaba.
# H
# Solo me aburri, nada personal
# Esperare xd
# V
# Gctxyf
# Me desconecto de las redes sociales
# ....
# Ya no tengo tiempo
# No utilizaba la app
# Muy buena app pero quisiera inociar desde cero
# No uso más la app
# Ihhg
# Nadie contestaba mis mensajes!
# Hay gente que se piensan que están en Badoo
# K
# Si
# W
# No creo que vaya a usarlo mucho
# La gente utiliza la aplicación para ligar no para aprender otro idioma
# No
# Si
# No uso
# Voy a estudiar sola.
# No tengo tiempo para contestar
# No la usaba
# Personas h
# 学习
# después abriré otra cuenta
# Cree otra cuenta
# X
# Gracias en otro momento
# Nadie me quería ayudar a aprender inglés
# School
# otro
# Me gusta mucho esta aplicación les doy un 10 de 10 pero en este momento quiero estar fuera de todas las redes sociales ♥️ y de todas las aplicaciones
# H
# Volveré
# N
# Yes
# Ya tengo otra cuenta
# Otro
# Ya no la necesito
# Ya no quiero usar la app
# Mi decision
# Quiero borrarla porque ya no hablo con las personas de mis chats y quiero crear una cuenta nueva
# Hhhh
# Ya no tengo tiempo de utilizarla
# Otro
# Situación personal. Es una buena aplicación. Más adelante abriré un nuevo perfil.
# .
# X
# Gracias
# Intento encnotrar amigos, pero no es lo mismo que antes. La gente solo le interesa ligar.
# Estuve satisfecha con la aplicación pero ya no la necesito.
# Alegaron que mi perfil era falso, eso me ofendió bastante.
# nue
# Aprendi y conocí a alguien maravillosa
# No hay razon
# Ok
# No tengo tiempo
# Porque quiero.
# Aburrido
# Malgasto mi valioso tiempo
# No tengo tiempo de usarla
# No me gusta
# No hayo intercambio de chat
# No lo uso más
# Mxmskaksma
# Por seguridad
# Me aburri
# La gente esta mas en busca de pareja que en aprender algo
# Situaciones personales
# Las notificaciones llegan tarde
# Aprendi el idioma
# Ya no uso tandem
# Queria descansar un tiempo
# Debo hacer tareas
# .
# Por que voy a crear una nueva cuenta de tándem
# Volvere
# Bf
# Ok
# Porque rellene mal mi información
# Hhhj
# Quiero practicar con personas cercanas a mi municipio, pero tengo que pagar por ello
# H
# Personal
# Error
# ........0
# Me dejo de interesar
# BxnJka
# Ptro
# A
# Problemas personales
# Ya encontré con quien hablar
# Nothing wrong, I just wanted ti leave
# No me interesa
# X
# Nuevo comienzo
# Me abstengo
# Ya no me interesa la app
# No la uso diariamente
# W
# Vhj
# No quería hablar todo el tiempo con todo el mundo y tenía muchas conversaciones pendientes
# Esto es temporal. Volveré
# Problemas personales
# Pq si
# M
# Nkhhjk
# No quiero
# Porque sí
# Simplemente ya no quería usarla.
# Nada
# No tengo tiempo
# La app es muy buena pero todo tiene su final
# Aprendi perfeitamente a língua que desejava e agora moro um país dessa língua. Obrigado pela app. Ajudou-me muito
# Asunto Personal
# Es una aplicación para ligar
# Sin palabras gracias nos veremos pronto
# .
# No me siento comoda
# Volvere
# Pienso volver después! :D
# W
# No tengo tiempo ahora de usar la app
# Esta chafa
# YshxhkKaa0a
# Parece que todos entran a ligar y para nada hacen login para aprender.
# .
# Nada
# D
# Las personas en su mayoría hombres   querian conquistar no practicar. Además quienes me escribieron era de mi pais. (no eran nativos del habla inglés)
# No me gusta
# no quiero formar parte de la app
# Si
# No tengo tiempo
# He recibido mensajes de extraños a mi número privado diciendo que me conocieron en Tadem, peroa estas personas no les di mi número. Exactamente dos chico de India. Me pasó este año y el año pasado, ahora mi celular parece hackeado. Mejoren la seguridad.
# Yyyu
# Nada en particular
# C
# Me cobraron suscripción automáticamente
# Jj
# Espacio en mi cel
# F eke k kd xk  dkz xkd xk
# Voy a cambiar mi correo
# Quiero reconfigurar mi cuenta
# No me gustó
# Por que si
# Personal
# Vkohch
# La gente no es constante hablando
# Otros
# .
# No
# Aburrido
# Llll
# .
# No me pareció  tan interesante
# Otros
# No la uso
# Ya no quiero
# Necesito crear un perfil nuevo
# Otros
# Había perdido esa cuenta, por alguna extraña razón ya no podía entrar, así que hace algunos meses estoy usando otra cuenta en tandem y por qué tener dos? La borré
# Si
# Debo estar más preparado en idiomas.
# Ya no quiero una app así por el momento. Gracias
# No uso la app
# Simplemente ya no quiero usar la app
# Ce n'est pas pour moi
# Otra
# Otra
# Ji
# Errore
# Sorry
# .
# No me apetece tenerla
# N
# .
# J
# .
# I don’t like it
# .
# Nothing
# Loma
# Que les importa
# ...................
# Quería hacerlo
# Ya he aprendido y agradezco
# A
# Puedo aprender un idioma de maneras más prácticas; no necesito tandem
# Ya no quiero usarla
# .
# Espero usarla en un futuro
# Nothing
# Es temporal
# Veheheuud
# No es de mi relevancia
# Me genera inseguridad la app
# T
# Detox de redes
# Nada en específico
# No quiero continuar
# Quiero empezar de nuevo
# just because
# .
# Estoy muy ocupada
# I'm going to the University. So i won't have time. Thanks for all!!!
# W
# No deseo utilizar la app
# Bhhh
# No se
# No tengo mucho tiempo gracias por todo buena app
# N
# Nothing
# Se trababa la aplicación
# paso mucho tiempo y quier dar un tiempo para el telefono
# Tengo muchas ocupaciones y no me queda tiempo para utilizar la app
# W
# No me gusto
# Una persona me habla de cosas sin sentido, realmente es molesto.
# s
# Cosas personales
# Mis padres me pidieron que la eliminara
# No tengo tiempo
# Me aburrí
# Stupid
# Unfortunately, I recieved too many request from guys confusing the app with tinder and constantly hitting on me.
# No me hisroi
# Solo quiero irme
# No motivo
# No la voy a usar
# Nada
# Ya no la necesito
# Nadie habla
# Motivos personales
# Hol
# Un tipo grosero de brasil
# .
# Sinceramente, no es lo mismo que antes
# No quiero seguir
# Nadie respondía mis mensajes.
# Quiero descansar
# Voy primero a mejorar el idioma.
# ..
# Prefiero hacerlo en directo que a través de móvil
# No tengo tiempo
# No usa
# Otro.
# No tengo tiempo
# Encontré a alguien especial
# Nada
# .
# Me gustaría hacer otras cosas
# .
# Ya ni tengo tiempo
# F
# Ya no la necesito
# Outro
# Volveré
# Prefiero no usar
# Otro
# Las personas no son interesantes
# Quiero partir denuevo
# Uqtejsjdjd
# Me gustó mucho la app para conocer gente nueva y de sus culturas, pero me absorbía mucho tiempo, es posible que vuelva pronto :)
# Cambié mi edad sin querer y ahora me aparecen adultos solamente
# Los usuarios hombres le hablan a las mujeres para intereses sexuales y es ofensivo
# Nothing worse
# No lo necesito actualmente
# Nada
# No tengo tiempo
# Porque quiero.
# .
# No me gusta
# W
# Creo que la edad influye para establecer conversación para aprender un idioma. Pues fue mi sensación, y más que pareciera más un sitio de ligar que de aprender. Saludos
# Nada
# No mas
# Otro
# Me cree otra cuenta Gmail
# Nothing
# No importa
# W
# Nothing
# Nada
# Faltan herramientas, me gusta más el formato de hellotalk
# No es lo mio, geacias
# .
# Otro
# Banda mmg
# Jsjss
# Tiempo para su uso
# Encontré 2 amigos que me ayudan ya por fuera de esta app
# Descanso
# Me hablaban como si fuera un sitio de citas, un chico me habló y siguió persistiendo a pesar de que le dije que me incomodaba. Hubo unos que me pedían mi perfil de Instagram o número de teléfono, en algunos casos fotos de mí. No fue de mi agrado.
# ya quiero salirme
# No contestan las personas con las que deseas practicar el idioma
# Falta de espacio en mi celular
# Me gustaría hablar con personas un poco mayores que yo
# Pues no tengo mucho espacio, y no tengo tiempo para estar contestando todos los mensajes
# Jjkiogh bj
# Me aburri
# Bye
# Me aburri
# Otro
# No puedo borrar mis chats
# No me gustó la app
# O
# .
# Ay
# W
# Nada no tengo tiempo, muy buena aplicación
# ........
# No usaba casi la app
# Nunca recibí un mensaje
# .
# W
# Nada
# Quiero darme un tiempo, pero espero volver
# Ya no quería seguir usándola
# No quiero seguir
# La mayoría usa el sitio para citas
# Otro
# Thanks
# W
# Otro personal
# Ya no la uso por falta de tiempo
# No sabia como usarlo
# Jshdvfk
# Otro
# Nada grave
# Cambiar de correo
# Las personas solo te piden nudes :)
# Me acosaban creyendo que yo era una persona fácil por ser mexicana
# Jjjjh
# Fddse
# Casi no utilizo la app
# Otro
# Quiero salir
# Estoy ocupada con otras cosas
# Ya tengo una cuenta creada
# Otro
# Nossd
# Mi perfil no se visualiza de manera pública, entonces nadie me habla, y las veces que intenté escribirle a alguien me respondia cada siglo
# Problemas
# Dcc
# Mm
# .k
# Nothing
# .......
# Ul
# G
# Sin razón
# Tiempo
# .
# D
# Another person is using my Tandem account without my permission, and TandemSupport says that they can't help me to solve that problem
# Ya Aprendí lo que necesitaba
# X
# Encontré a alguien
# Tengo dos cuentas por error. Mejor elimino esta y me quedo con la otra
# Modo de conversación muy lento, tanto que aburre esperar
# Quiero enfocarme en algo mas
# Vbjjnyt  yubin ubibyt y bh  t y
# .
# No time
# Jnn
# ...
# .
# otro
# j
# Ya no quieto seguir usando está aplicación
# Falta de espacio en mi teléfono
# F
# Quería cambiarle la ubicación pero desde una cuenta nueva
# G
# Nadie me quiere :(
# Me robaron mi celular y estoy por adquirir nuevo equipo
# No lo estaba utilizando, la app es muy buena, pero llegan demasiados mensajes
# Perdí mi cuenta anterior la quiero recuperar
# Volvere
# Tengo miedo de que me enseñen penes i cosas de esas
# Me aburrió
# Yo que se
# Jjjjj
# Bbbjxxbnd rjdjd
# Pervertidos
# Solo era momento de hacerlo
# No estoy lista
# No me hablan
# Nada
# F
# Kkjh
# N
# Me sentí insegura
# Yuj
# Sjdjdk
# Sólo me aburrí jajaj
# I needed to change my name because I'm 46 and in my name appeared forty. As I had changed it once I couldn't change it. I thing this feature is something that can be improved
# Temporalmente
# G
# No me llama la atención
# No me dejaba cambiar la foto
# Las personas no responden a tus mensajes. O se demoran un montón de tiempo para una respuesta. Parece que no tienen ganas de aprender un idioma
# No es buena
# Nada
# Me distrae mucho.
# Todo iba bien hasta que me enamoré de un usuario y no era lo que buscaba. Es mi responsabilidad. De todos modos muy buena app. Gracias. Espero volver pronto
# No
# No tuve conversaciones significativas en el tiempo que lo usé, quiero empezar de nuevo desde cero.
# ..
# Me equivoqué
# Nada
# nothing
# Je ne suis plus intéressée
# Je prefere le apprentisage de la vie reel
# Je n’ai plus le temps de utiliser l’application
# Jj
# Rien de special
# Occupé
# Ttt
# Pas de raison
# Jfkdk
# J'avais demandé au modératrice "Elle, 35 de Tarlac City - Philippines" d'exclure une jeune fille du nom de Mila, 20 habitant Poltava en Ukraine, référencé @mila6778177; après que cette dernière m'avait insulté de  entre autres. Votre modératrice a refusé de le faire, alors je quitte votre application.
# J
# Je cherchais principalement à apprendre le néerlandais (et un peu l'anglais) et je n'ai trouvé que des tandems anglophones
# .
# I
# H
# En couple
# Pas de raison
# ...
# Muita notificação
# Só quero excluir mesmo
# Já estou grato
# quero refazer minha conta
# W
# No más
# Don’t have time anymore
# Nao preciso mais
# Ww
# O
# w
# K
# Na
# Ninguém me respondia nessa merda
# Hxjddn
# nao me sinto segura
# Outro motivo
# jejdjididodod
# desisti
# Não quero mais usar o app
# Outro
# Nada abusei
# Pessoas sem disposição para ajudar
# Minha memória está cheia
# Estou sem tempo
# '-
# ..
# É isso
# Não quero mais
# Eu quis excluir mesmo
# ......
# Recriar
# Kskskksskks
# Outro
# Tive uma má experiência com conversas online no geral.
# Aaaa
# Aparentemente essa email é de outra conta minha
# Jjg
# Irei fazer outra
# Não tenho mais interesse
# V
# Não me ajudou muito
# I don't have time
# Nada
# Entrei com a conta errada
# Outros
# Não quero mais
# Zzhzhsz
# Ninguém conversa comigo
# Não tive resultado
# Segurança
# Quero começar de novo
# .
# Outros
# Ok
# Jhgg
# Falta de segurança principalmente com fotos do perfil pois qualquer um pode tirar print
# Kjhh
# Razões pessoais
# N quero mais usar
# ...
# Vou fazer putra conta
# Ahauahaua
# Estou satisfeita.
# Não esyoubmaisnaorenden
# Não quero mais
# Jrjd
# ...
# ...
# Já aprendi o que precisava
# Cansei de usar e quero excluir
# Ñ quero mais
# ...
# Estou sem tempo de praticar
# Outro
# W
# Nada não. Só fiquei um dia mesmo e pronto.
# Preciso de um tempinho pra mim,mas o aplicativo é ótimo
# Bap
# .
# Sem tempo
# N
# Jjjjhsjsvsj
# Estava sem tempo para usar
# Namorado
# .
# muito chat
# não tenho tempo
# Cansei
# Não quero
# Kgfuom
# Motivo pessoal, não ocorreal enhum problema
# Pessoas estão usando esse app como rede social para adultos e pra mim não interessa isso é sim o aprendizado
# W
# Não tô mais aprendendo idiomas.
# Já achei o que eu procurava
# Quero refazer minha conta
# Não tenho confiança nesse app
# Me sinto insegura com a localização
# Opção de limpar conversa.
# Enjoei
# Não quero dizwr
# Ninguém responde ...
# .
# Vou voltar
# Razões totalmente pessoais
# Não quero mais usar
# Excluir permanentemente
# Vou fazer outra  conta
# Ok
# Não podia apagar alguma mensagem caso aenviasse por engano, ou me arrependesse.
# .
# Encontrei outro
# Só queria conhecer
# A
# Por motivos pessoais tive que sair
# EU quero
# Nada
# Excluir permanentemente
# The app is amazing, I'm just trying one thing with a secondary account 😅😅
# Não thanks
# Não quero
# Quero excluir definitivamente
# Nada
# N quero mais participar
# Preciso liberar espaço de memória no celular.
# Não estou tendo tempo para praticar
# Todos que segui tá conseguir aprender outro idioma, me ignoraram por completo, notei que só respondiam pessoas de outro sexo e de aparência acima do padrão.
# Jjjj
# Outro
# Delete
# C
# Preciso fazer um tratamento de saúde
# .
# Já adquiri competências necessárias
# Sem tempo para usa App ultimamente,não gosto de deixa ninguém no vácuo
# .
# Aaáaaa
# Nhgu
# a
# Pessoal
# Sla
# Opção minha
# Si
# Memória
# Eu mandei menssagens para várias pessoas e não recebi respostas. Uma pessoas me mandou mensagem e quando fui ver as conversas, não tinha nada. Não sei se foi um erro isolado ou se pessoas falavam comigo e eu não conseguia ver
# Sem tempo
# fiquei com preguiça
# Fiquei sem vontade de usar
# O aplicativo é ótimo
# Ok
# Ok
# To aafim
# Tive que sair por um tempo, mas o aplicativo é incrível
# Não estava utilizando
# Sem tempo
# Lalalalala
# Cansei mesmo
# Motivos pessoais
# Não uso
# I have a girlfriend and she is against
# O APP E ÓTIMO MAIS EU NÃO PERDENDO USAR POR AGORA.
# Muito atarefada, com pouco tempo para praticar.
# Nada
# 🙄
# Depois volto
# Fiz merda
# Estou sem tempo para praticar
# ..
# Nenxnsnsndnrb
# Não preciso mais.
# Ll
# De momento não tenho tempo e não sei quando vou ter
# ....
# Não fiquei a vontade com minha foto
# K
# Goodbye
# Kkkkkkkkk
# Be back soon
# Vocês renovam automaticamente o após 24 a conta e não oferecem uma forma fluída e eficaz para cancelar
# W
# A
# Outro
# Nao tenho.mais dinheiro
# Cobrança indevida! Fui roubado! Vocês deviam ter vergonha! Bando de ladrões!!!
# Organização
# Não estou com saúde mental no momento
# Coração partido
# Ninguém conversou comigo
# n quero mais
# Meu irmão acha que eu sou muito nova para estar no aplicativo
# Sim
# Apenas apagar.
# Não tenho dinheiro
# Nwja
# Não consegui exclui uma foto!
# Sem interesse
# Não quero mais
# Só não quero usar o app no momento
# cansei
# Depois volto
# Outro tttttt
# Só quero excluir
# Excluir permanentemente
# Não me dei muito bem no app, mas o app é ótimo só eu q não me adaptei muito bem
# Não estou sendo tempo para usar o app, mas ele é muito b
# .....vv
# Não me interessa mais
# Ynxvbnn
# Não quero mais
# Está apenas curiosa para saber como era o aplicativo
# Putdigivhkjc
# Quero sair e excluir a conta apenas
# Meu celular está sem espaço
# Quero fazer um novo perfil
# Bye
# Não quero mais
# Eu mandei mensagem para vários usuários para começar uma conversa, mas ninguém me responde
# Outro
# As pessoas não me respondiam
# Naonquero mais
# W
# Quarentena
# Sem interesse
# Não quero continuar
# Ninguém responde e fica online para desenvolver uma conversa
# Homens em busca de sexo, ao invés de trocar informações
# Outro
# Não tenho com quem conversar
# Não tinha tempo para responder as mensagens
# dvdcfffdfgdcgs
# Cansei do app
# Coloquei um perfil de idade e só apareceu jovens. Percebi que o intuito era outro e não gostei. Não apareceu ninguém para falar alemão. Está parecendo um site de relacionamento amoroso.
# Bjjhghjkh
# Jjnnvggjll
# Não me ajudou ;-;
# Não
# Outro
# Nggiouytuioooiiog
# Eu nao uso muito
# Sem coragem pra utilizar
# Assédio
# Ohfiifctuxtx
# Por enquanto estarei dando uma pausa no aplicativo
# .
# Ok
# Bbyin
# Cansei
# Não me adaptei ao aplicativo.
# Só não quero mais usar mesmo, uma amiga minha me falou pra baixar pra ver como é
# Pq quis
# Quando excluo as conversa não encontro mais a pessoa
# Outro
# Estou sem tempo
# .
# Não quero mais
# Motivos pessoais
# atoa ndjnrjdnd
# O app é muito interessante, mas percebi que ainda não estou preparado para essa ferramenta
# Porque sim
# G
# Conheci alguém
# Não quero mais só isso
# A
# Muitas pessoas usam o aplicativo como app de namoro, nada contra app de namoro mas esse não é o objetivo. Pessoas até um tanto desrespeitosas, não dá pra ficar o tempo todo só bloqueando usuário.
# Criar outra conta
# Outro
# Parece um Tinder...pessimo
# Sem tempo
# Nada
# Enjoei
# Quero deletar
# O problema não é vocês e sim,porque, eu não consigo me socializar sou uma pessoa repulsiva
# Vou desenvolver mais o meu inglês básico antes te voltar ao Tadem
# Eu não fiz amizade
# Rzrzrzrzsrrzzzrzrz
# Estava travando muito
# Não quero mais
# Preguiça
# .
# Tempo corrido
# Eu só quero excluir
# Estou sem tempo para mexer no app.
# Quero aprender a falar melhor e depois eu volto.
# Uuu
# Vou criar outra conta
# A
# Vgcvbngh
# Sem tempo
# Vou fazer uma conta nova
# Não quero estar em uma nova rede social agora.
# Entrei pra saber como era
# ninguém falava comigo
# Kj
# Não quero mais
# Outros motivos
# Não quero mais
# Atoa
# I'm not studying Japanese anymore, but maybe I come back cause is a great app
# Estou sem tempo
# Eu voltarei
# Porque a maior parte do conteúdo é pago
# Não quero mais
# Nnnbkbv
# .
# Motivo diverso
# estou excluindo por um tempo
# As pessoas não falam comigo.😢
# Não quero mais
# Nada
# .
# Nothing
# Não tive uma boa experiência
# Estou mudando de e-mail
# Outro
# Eu quis
# Problemas financeiros
# Prefiro não comentar!
# Motivos pessoais
# Não quero
# Cccccccc
# Eu aprendi muita coisas já
# Porque eu quero
# Meus sentimentos.
# Excluir permanentemente
# Perdi o interesse
# Eu aprendi o idioma que eu queria
# Inininoy7c6tx6tc6otf6f 6y vc 7y
# Não uso mais
# Tempo
# Não gostei da experiência
# Outro app
# Não gostei
# Ghhdijhgs
# .
# Parece um app de putaria, todo mundo só quer enviar nudes
# desanimei sozinho
# As pessoas não querem se ajudar pra aprender outra língua, orgulhosos.
# Quero começar de novo pq tem muitas pessoas
# Falta de tempo
# Outros
# Sem tempo pra utilizar
# nao quero mais usar
# Razões totalmente pessoais
# Nada
# Outros motivos
# .
# Sou tímida
# .
# Tenho outras prioridades.
# Não quero mais usar
# Meus links todos seja do que for abrem o aplicativo
# Excluir permanente minha conta
# Ok
# Outro motivo
# Eu tenho outra conta que estou tentando recuperar
# Atia
# Mandei mensagens para diversas pessoas, mas só 5 me responderam. E essas só respondem as minhas perguntas depois de HORAS e a cada outra pergunta o mesmo tempo.
# Nada
# Recomeçando
# .
# Enjoei do app
# Já tenho uma outra conta.
# Apenas excluir
# É assustador. Somente recebi mensagens de homens e isso me fez insegura. Não parece que estão dispostos a ensinar.
# Não quero mais
# Outras prioridades
# I dont want
# Ok
# Просто
# Не понравилось
# W
# (((
# мало красивых парней
# Мой парень не разрешает
# .
# Vyhgh
# Стало скучно
# Нет места в телефоне
# i found my love and don't need tandem account at this moment
# Thank you
# Пока нет свободного времени
# Личные обстоятельства
# Не хочу
# Я допустила ошибку при регистрации
# Лддддд
# K
# .
# Мне грустно
# .
# ...
# Another reason.
# Thank you
# ..
# 6ihinuhg
# Мне это больше не нужно
# Just
# Наверное, просто не для меня
# Просто
# kskss sjsjd
# Thank you
# ахаххаха
# Просто надоело
# Неаитивеый ебконтент
# .
# Удалились все диалоги, геометка мешает при просмотре профилей "людей поблизости"
# My heart is broken
# За каждый шаг спрашиваете деньги и оплату
# Другое
# Ы
# Приложение списало денежные средства , раньше 7 дней бесплатного пользования
# L
# 1234
# Из всех собеседников, практически никто не выделяет времени, никаких ответных действий. Нет желания или нет времени у собеседников отвечать или даже читать Мои сообщения. А если нет ответного контакта, чему жж тогда Я научусь
# Ролдиапллдбт
# Адвдла
# Норма
# Я профиль создал и не разобрался как его редактировать по этому сейчас создам новый профиль
# Надоело
# Просто так решила
# Не могу написать своему собеседнику
# Все кто здесь зарегистрирован кажется спутали его с приложением для знакомств
# Нет времени
# ......
# Дорого
# Khjk
# ....
# —-
# ....
# У меня не хватает времени изучать.
# C
# .
# W
# Просто
# Не хочу
# Thank you
# Не хочу
# Chuss
# Другое
# Нету времени
# За ненадобностью
# H
# Нашла постоянного собеседника
# Пока неактуально
# Передумал
# Другое
# На данное время я не могу заниматься
# h
# Плохо работает
# Самый тупой приложение в котором я когда-то видел! Мне не удалось восстановить аккаунт!
# Для меня слишком тяжело общаться с людьми в моральном плане.
# Мне приложение понравилось
# Просто
# Создала по ошибке , пытаюсь войти в свой аккаунт с другого устройства
# .
# .
# Очень скучное приложение.
# Thank you
# Надоело
# ....
# Chuzeci
# Enother reason
# Другое
# ..
# Личные обстоятельства
# муж не одобряет
# Nnn
# Мне не нравится здесь общаться
# Другое
# Другое
# Не хочу больше общаться
# Просто
# Другое
# ....................
# .
# Ааа
# S
# пп
# ...
# Just so
# Meh
# Другое
# Я создал новый аккаунт
# I found friends
# я устала
# /\
# It's okay
# Было трудно изучать язык с людьми.. которые переходили за рамки приличия. (Будто это сайт знакомств) но здесь иногда можно найти интересных собеседников. За это отдельное спасибо.
# Thank you
# Нет времени
# Оз
# Ририо
# Па
# '-
# Просто хочу удалить
# Благодаря вашему приложению я нашла человека с которым общаюсь каждый день в другом приложении
# Просто
# Некогда
# ...
# не хочу больше пользоваться им
# Не хочу общаться больше
# Ш
# ...
# Мне тяжело общаться с людьми напрямую. Я поняла, что не готова к этому.
# Р
# Кхм
# Мне никто из собеседников не отвечал. Читали моё сообщение, и не отвечали.
# П
# T
# .
# ——
# Другое
# Нет времени
# .
# Просто
# не нуждаюсь больше
# .
# Мне это не нужно
# Ок
# О
# Ок
# Устал
# Невозможно найти тандем партнёра большинство сообщений не прочитыааются. Переписка останавливается в любой момент.  Не понятно зачем тратить время и силы если люди просто не оьщаются? Положительный опыт тоже был что радует. Но это был единственный случай!
# Thank you
# Security
# Whatever
# hjmmjjjkk
# хотелось общаться с девушками, потому что мне так комфортнее, но писали только одни мужики и заполонили мои сообщения. это пугает немного, извините
# .
# Я не смог менять свой имя
# Мне никто не пишет
# ....
# Нет возможности пользоваться приложением
# Самоучка
# Другое
# Only i don't want to use this app
# I have found someone who helps me with teaching. We teach each other at skype - it is more conviniante
# .
# Just
# При
# Я хочу вернуться в прошлый аккаунт
# It's okay
# .
# Собеседники не так активны:(
# W
# я устала
# Дело не в вас, дело во мне
# nothing
# hhhhhbhhhhh
# КАЖДЫЙ ДЕНЬ ОУ ДА Я НА ТРЕПЕ ДО УТРА
# Я мало общителен
# Конфиденциальность
# Not using
# мне никто не пишет
# Пока не охото
# '-
# .
# Не понравилось
# Я познакомилась здесь с "чудесным" парнем, который затем разбил мне сердце. Приложение тут не причём(оно отличное), мне просто нужно время. Спасибо
# вы крутые, просто это не для меня
# !
# !
# ...........
# Нужно удалить приложение мало места, а я здесь редко общаюсь
# ...
# Роо
# МНЕ АБСОЛЮТНО НЕ ПОНРАВИЛОСЬ ПРИЛОЖЕНИЕ! ЖМОТЫ, ИМ ТОЛЬКО ДЕНЬГИ ПОДАВАЙ! ДАЖЕ ПРИ РЕГИСТРАЦИИ ДЕНЬГИ ПЛАТИ. СРАМ!
# просто не хочу  быть вэтом приложениио
# Скучно
# ....
# Нашла того с кем буду практиковать язык
# .
# Я встретила того кого хотела
# Спасибо
# .
# Другое
# Просто
# Пока нет времени
# Не хватает времени
# Фейки
# Hbfy
# Thank you
# V
# Я хотел стать преподавателем!
# Со мной ни кто не хочет общаться
# Меня все игнорят,уже месяц как не могу нормально общаться с людьми
# ...
# Полироо
# Р
# По личным обстоятельствам
# .
# Я не хочу отвечать на этот вопрос
# Не хочу
# Рсоптптплптп
# У меня есть второй аккаунт
# Я нашла очень хорошую подругу, с которой нам удобнее общатсья в социальных сетях, нежели здесь. Она из Индонезии и у нас одинаковый уровень владения языком, поэтому благодаря рекомендациям тандем я нашла её. Спасибо за то что подкинули её профиль ко мне в рекомендации
# Нельзя удалять Сообщения
# Hbvhcfvvvg
# Пока
# G
# Просто не понравилось
# I don't have enough time
# Нашла партнёра для общения, и мы общаемся в другой социальной сети
# Пожалуйста проверяйте тщательно информацию людей регистрирующихся в тандеме!Я попала на реального мошенника,который общался с людьми под чужим именем ,чужим профилем и чужими фотографиями !Это ужасно!Тандем обещал нам реальных людей!
# мне просто нужно удалить аккаунт
# Другое
# I asked lots of friends to sign up for me and they did but never showed in my friend list and I also couldn't invite anyone else anymore, what the hell?? Fix it damn
# ..
# ¯\_(ツ)_/¯
# Я боюсь и смущена разговаривать по звонку с иностранцами, а переписки мне недостаточно
# Я не хочу использовать своё фото
# ...
# Арлдорасмивклбтипрдбма
# .
# Я не могу поменять аватар...он не сохраняется.придется удалить
# .
# Thank you
# H
# ..былай
# я ничего не хочу
# Because
# .
# ?
# Ыоов
# Просто так захотелось
# 我要学英语，选了日语，不能换成英语
# 不知道
# 我有一点社交恐惧，有人过来和我说话或者看我的档案会有一点害怕
# 我不太适合这个软件
# 其他
# 不习惯用
# nothing
# 没时间
# 很伤心
# .
# ，
# 搜索不到好友
# 我打算用另一个国际社交软件了
# 个人原因
# 网络
# 无
# ‘
# 软件实际上并没有多少人
# 男女情感间的对话也是语言交换的话题之一，就算发展成朋友，约会不行吗？这个软件估计会愈来愈少，被取代
# 没人聊天
# 不怎么用
# 完全找不到小伙伴聊天，我不会用这个软件
# 不想用了
# 多余的
# 无法发视频
# 不想用了
# 没有人愿意理我
# 暂时不想用
# 不能删除信息
# 喜欢的女孩子注销了
# 换个号码登录
# 其他
# W
# 我的好朋友找不到了
# 没关系 你们做的很好 加油！
# 无聊
# a
# 。
# 123456tt
# 。
# 不需要了
# 略略略
# 没有时间
# 上学了，我爬
# 不想用了
# 。
# q
# 想重来
# 我的信息写错了。
# 。
# 没有人搭理我
# 我…社恐……
# 卸载
# 忙于学习
# 工作忙没有很多时间
# 。
# 我希望可以自由的删除和别人的聊天记录。
# 不想用了
# 都是假的   没有聊天的动力，没人回信息
# 重新开始
# 嗯
# 没什么
# 用不来
# 有点迷茫
# ？
# 汉字请用简体中文，别用繁体谢谢。
# ?
# 到学校入册侧壁
# 不太健谈
# 1
# 228900
# abc
# 要钱我没钱
# 无
# 蹴鞠筹措飓风vi几点到空白处可能出现回来吧v
# 无
# 我因为这个收到了微信骚扰
# 头像总是变成空白，别人的同学也总是刷不出来，很烦躁
# 。。。
# 我和其他网友的名字都是灰色的头像根本就没有头像
# 定位信息无法修改
# 不想玩了
# 因为我想重新注册
# 没人聊天
# 我的ID写错了
# 好好学习
# 聊天聊着聊着就没聊天框了 给别人发消息也不回复 没有几个人找我聊天
# 重新申请
# 不能删？
# 。。
# 不想用
# 没有人回回答
# 重新建立账户
# 我想修改资料
# 无法换头像
# 我的信息填写错误了
# 用不到了
# F
# 无
# 主动和我谈话的都是日语教学机构 很无语
# 因为我不想用了
# 我的聊天朋友突然就没了。什么都没了。找不到了。
# Some people sent me questions about political racism.
# I don't know why should we post our own profile picture. Furthermore, people in this app always look for other people appearance. For someone who doesn't have a good appearance, nobody will even talk to them. When we post a very beautiful or very handsome profile, many people come to talk, i think this is a bit offensive for some people. There's a saying"人不可貌相，海水不可斗量"which means we can't judge a book by it's cover. I think appearance is not important in language learning, the important things are how to talk , behave and how we help each other in language. I know how hypocrite human is. But please understand that this is not even a dating app, so why should we show our appearance? This app is good basically, it helps me improve my Chinese. I help a lot of people in English, But in the end many people reported me because I don't use my own profile picture. Isn't it ridiculous? This app is making me dissapointed. Please consider this.
# 想换一个名字
# 太假了  妈的  骗了我一月会员
# 没有原因
# 注册了之后我的邮箱隔三差五就收到垃圾邮件，/希望你们能够处理好这个问题
# 无法改年龄。
# 无
# y
# 无
# 哦
# 不想用了
# 无
# 年龄无法更改，想要重新开始
# 这软件很好
# 别人不理我
# 1
# 无
# bug
# 不想用了
# i am lonely. sry
# 邮件发的太频繁了
# 不想用了
# 个人原因
# 高中生活学习忙碌，尝尝无暇顾及软件里面信息，又因经常被发邮箱提醒，让我感觉怪不好意思的，于是注销了账号。软件本身很好而且我也很喜欢！谢谢。
# 信息登陆错误
# 无
# 哦哦哦
# en
# 人们总是来了又走，这让人很失落
# h
# ，，，，
# 。
# 没有原因
# 有了新的账号
# 有人举报我因为不是使用真人图片，但是平上也有很多没有使用真人图片这不公平
# 我跟換頭像時發生未知錯誤
# 爽啦
# Z
# nothing
# 已經學到足夠多的東西很滿足了 接下來打算常識其他的方式繼續學習語言
# 要錢

# %%
master = pd.read_excel("EN.xlsx")

# stitch together all the files
for lang in languages:
    print master.shape
    filename = lang + ".xlsx"
    new_file = pd.read_excel(filename)
    new_cols = {x: y for x, y in zip(new_file.columns, master.columns)}
    master = master.append(new_file.rename(columns=new_cols))
    
# split into iOS and Android
is_android = master.iloc[:,36] == "Android"
is_ios = master.iloc[:,36] != "Android"
df_android = master[is_android]
df_ios = master[is_ios]

df_android.to_excel("df_android.xlsx", index = False)
df_ios.to_excel("df_ios.xlsx", index = False)
master.to_excel("df_concatenated.xlsx", index = False)

print "Total Android Size:" + str(df_android.shape)
print "Total iOS Size:" + str(df_ios.shape)
# Out:
# (29796, 40)
# (59592, 40)
# (62996, 40)
# (77347, 40)
# (81688, 40)
# (84409, 40)
# (88412, 40)
# (94019, 40)
# (104725, 40)
# (113890, 40)
# (117808, 40)
# Total Android Size:(67110, 40)
# Total iOS Size:(51071, 40)

# %%
# run analyse function on each language with built in print function 
languages = ["EN","DE","ES","FR","IT","JP","KO","PT","RU","ZHS","ZHT"]
for lang in languages:
    analyse(lang)
    print_results("language")
# Out:
# Total EN: 29796
# ----------EN----------
# -
# Mainly one language: 3618
# Didn't develop into meaningful convo: 12368
# The app is not what I expected: 11058
# There were too many scammers // fake profiles: 4437
# I couldn't find anyone to talk to: 15793
# The app didn't help me much with my language learning: 9268
# I received too many messages on Tandem: 4095
# I received too many calls on Tandem that I didn't want to take: 1958
# Someone offended or annoyed me: 3702
# I had technical problems using the app: 2559:Android: 1423 // 2.12039934436% :iOS: 1136 // 2.22435433025%
# Takes too much space: 4639:Android: 2802 // 4.17523468932%:iOS: 1586 // 3.10548060543%
# App drains battery: 3519:Android: 1933 // 2.88034570109%:iOS: 1586 // 3.10548060543%
# Too many push notifications: 2372:Android: 1399 // 2.08463716287%:iOS: 973 // 1.90519081279%
# The app was confusing: 3333
# Not currently learning a lang: 7160
# Don't have time: 24137
# Want to change profile info: 4036
# Want to start a new account: 10958
# I am still a beginner: 8694
# It felt like a dating app: 11839
# Didn't want to pay for pro: 6304
# Using a different app: 3795
# Other: 4671
# -
# HelloTalk: 1313
# Speaky: 256
# Fylp: 100
# iTalki: 146
# OpenTalk: 91
# Lingebe: 78
# Bilingua: 102
# HelloPal: 101
# Duolingo: 978
# Ablo: 142
# InterPals: 103
# Other app: 3619
# ----- Technical ----
# Some messages not delivered: 577
# Some photos not delivered: 344
# Audio messages wouldn't play: 227
# The app froze or crashed: 804
# I didn't receive notifications: 484
# Messages or chats were out of order: 426
# Audio messages failed to send: 240
# Audio or video quality was really bad: 266
# Other technical problem: 254
# Total: 118181
# Android: 67110
# iOS: 51071
# Total DE: 3404
# ----------DE----------
# -
# Mainly one language: 3734
# Didn't develop into meaningful convo: 12695
# The app is not what I expected: 11427
# There were too many scammers // fake profiles: 4545
# I couldn't find anyone to talk to: 16029
# The app didn't help me much with my language learning: 9523
# I received too many messages on Tandem: 4377
# I received too many calls on Tandem that I didn't want to take: 2019
# Someone offended or annoyed me: 3743
# I had technical problems using the app: 2636:Android: 1461 // 2.12626615438% :iOS: 1175 // 2.22230628109%
# Takes too much space: 4723:Android: 2839 // 4.13173826988%:iOS: 1635 // 3.09231554858%
# App drains battery: 3606:Android: 1971 // 2.8684945861%:iOS: 1635 // 3.09231554858%
# Too many push notifications: 2464:Android: 1442 // 2.09861450693%:iOS: 1022 // 1.93293363342%
# The app was confusing: 3412
# Not currently learning a lang: 7407
# Don't have time: 24862
# Want to change profile info: 4109
# Want to start a new account: 11130
# I am still a beginner: 8908
# It felt like a dating app: 12316
# Didn't want to pay for pro: 6530
# Using a different app: 3893
# Other: 4802
# -
# HelloTalk: 1354
# Speaky: 261
# Fylp: 103
# iTalki: 149
# OpenTalk: 94
# Lingebe: 83
# Bilingua: 105
# HelloPal: 102
# Duolingo: 998
# Ablo: 145
# InterPals: 106
# Other app: 3735
# ----- Technical ----
# Some messages not delivered: 591
# Some photos not delivered: 349
# Audio messages wouldn't play: 229
# The app froze or crashed: 824
# I didn't receive notifications: 498
# Messages or chats were out of order: 445
# Audio messages failed to send: 248
# Audio or video quality was really bad: 273
# Other technical problem: 262
# Total: 121585
# Android: 68712
# iOS: 52873
# Total ES: 14351
# ----------ES----------
# -
# Mainly one language: 4232
# Didn't develop into meaningful convo: 14735
# The app is not what I expected: 12802
# There were too many scammers // fake profiles: 5113
# I couldn't find anyone to talk to: 18439
# The app didn't help me much with my language learning: 10710
# I received too many messages on Tandem: 4691
# I received too many calls on Tandem that I didn't want to take: 2199
# Someone offended or annoyed me: 4152
# I had technical problems using the app: 2943:Android: 1680 // 2.12206952304% :iOS: 1263 // 2.22484498309%
# Takes too much space: 5351:Android: 3306 // 4.17592966855%:iOS: 1782 // 3.13909244645%
# App drains battery: 4109:Android: 2327 // 2.93931891673%:iOS: 1782 // 3.13909244645%
# Too many push notifications: 2731:Android: 1653 // 2.08796483428%:iOS: 1078 // 1.89895715896%
# The app was confusing: 3919
# Not currently learning a lang: 8214
# Don't have time: 27712
# Want to change profile info: 4506
# Want to start a new account: 12117
# I am still a beginner: 10269
# It felt like a dating app: 13714
# Didn't want to pay for pro: 7309
# Using a different app: 4243
# Other: 5358
# -
# HelloTalk: 1438
# Speaky: 293
# Fylp: 112
# iTalki: 161
# OpenTalk: 99
# Lingebe: 85
# Bilingua: 114
# HelloPal: 107
# Duolingo: 1144
# Ablo: 157
# InterPals: 109
# Other app: 4233
# ----- Technical ----
# Some messages not delivered: 689
# Some photos not delivered: 380
# Audio messages wouldn't play: 256
# The app froze or crashed: 931
# I didn't receive notifications: 569
# Messages or chats were out of order: 478
# Audio messages failed to send: 282
# Audio or video quality was really bad: 303
# Other technical problem: 285
# Total: 135936
# Android: 79168
# iOS: 56768
# Total FR: 4341
# ----------FR----------
# -
# Mainly one language: 4400
# Didn't develop into meaningful convo: 15372
# The app is not what I expected: 13229
# There were too many scammers // fake profiles: 5255
# I couldn't find anyone to talk to: 18996
# The app didn't help me much with my language learning: 10960
# I received too many messages on Tandem: 4890
# I received too many calls on Tandem that I didn't want to take: 2292
# Someone offended or annoyed me: 4256
# I had technical problems using the app: 3050:Android: 1740 // 2.13706705969% :iOS: 1310 // 2.22573355761%
# Takes too much space: 5579:Android: 3424 // 4.20535494964%:iOS: 1844 // 3.13301731315%
# App drains battery: 4267:Android: 2423 // 2.97592729059%:iOS: 1844 // 3.13301731315%
# Too many push notifications: 2842:Android: 1715 // 2.1063620732%:iOS: 1127 // 1.91481047284%
# The app was confusing: 3988
# Not currently learning a lang: 8472
# Don't have time: 28602
# Want to change profile info: 4666
# Want to start a new account: 12478
# I am still a beginner: 10508
# It felt like a dating app: 14215
# Didn't want to pay for pro: 7520
# Using a different app: 4374
# Other: 5523
# -
# HelloTalk: 1487
# Speaky: 301
# Fylp: 114
# iTalki: 165
# OpenTalk: 100
# Lingebe: 88
# Bilingua: 119
# HelloPal: 113
# Duolingo: 1170
# Ablo: 161
# InterPals: 114
# Other app: 4401
# ----- Technical ----
# Some messages not delivered: 704
# Some photos not delivered: 392
# Audio messages wouldn't play: 265
# The app froze or crashed: 962
# I didn't receive notifications: 586
# Messages or chats were out of order: 499
# Audio messages failed to send: 292
# Audio or video quality was really bad: 309
# Other technical problem: 305
# Total: 140277
# Android: 81420
# iOS: 58857
# Total IT: 2721
# ----------IT----------
# -
# Mainly one language: 4505
# Didn't develop into meaningful convo: 15654
# The app is not what I expected: 13419
# There were too many scammers // fake profiles: 5389
# I couldn't find anyone to talk to: 19276
# The app didn't help me much with my language learning: 11106
# I received too many messages on Tandem: 5027
# I received too many calls on Tandem that I didn't want to take: 2337
# Someone offended or annoyed me: 4328
# I had technical problems using the app: 3105:Android: 1782 // 2.14520458896% :iOS: 1323 // 2.20761234127%
# Takes too much space: 5729:Android: 3519 // 4.23623734486%:iOS: 1902 // 3.17375561081%
# App drains battery: 4425:Android: 2523 // 3.03723410659%:iOS: 1902 // 3.17375561081%
# Too many push notifications: 2923:Android: 1768 // 2.12835112978%:iOS: 1155 // 1.92728061539%
# The app was confusing: 4019
# Not currently learning a lang: 8619
# Don't have time: 29137
# Want to change profile info: 4739
# Want to start a new account: 12692
# I am still a beginner: 10657
# It felt like a dating app: 14549
# Didn't want to pay for pro: 7637
# Using a different app: 4451
# Other: 5655
# -
# HelloTalk: 1521
# Speaky: 305
# Fylp: 115
# iTalki: 169
# OpenTalk: 102
# Lingebe: 88
# Bilingua: 124
# HelloPal: 117
# Duolingo: 1181
# Ablo: 164
# InterPals: 115
# Other app: 4506
# ----- Technical ----
# Some messages not delivered: 730
# Some photos not delivered: 397
# Audio messages wouldn't play: 268
# The app froze or crashed: 982
# I didn't receive notifications: 595
# Messages or chats were out of order: 508
# Audio messages failed to send: 297
# Audio or video quality was really bad: 313
# Other technical problem: 306
# Total: 142998
# Android: 83069
# iOS: 59929
# Total JP: 4003
# ----------JP----------
# -
# Mainly one language: 4598
# Didn't develop into meaningful convo: 15891
# The app is not what I expected: 13922
# There were too many scammers // fake profiles: 5556
# I couldn't find anyone to talk to: 19867
# The app didn't help me much with my language learning: 11453
# I received too many messages on Tandem: 5249
# I received too many calls on Tandem that I didn't want to take: 2541
# Someone offended or annoyed me: 4548
# I had technical problems using the app: 3147:Android: 1792 // 2.13501084185% :iOS: 1355 // 2.14850872881%
# Takes too much space: 5841:Android: 3559 // 4.2402363762%:iOS: 1965 // 3.1157340606%
# App drains battery: 4511:Android: 2546 // 3.03333571616%:iOS: 1965 // 3.1157340606%
# Too many push notifications: 3038:Android: 1804 // 2.14930778945%:iOS: 1234 // 1.95664927775%
# The app was confusing: 4285
# Not currently learning a lang: 8771
# Don't have time: 29881
# Want to change profile info: 4834
# Want to start a new account: 13000
# I am still a beginner: 10857
# It felt like a dating app: 15197
# Didn't want to pay for pro: 7815
# Using a different app: 4609
# Other: 5719
# -
# HelloTalk: 1634
# Speaky: 305
# Fylp: 117
# iTalki: 176
# OpenTalk: 104
# Lingebe: 89
# Bilingua: 126
# HelloPal: 122
# Duolingo: 1192
# Ablo: 165
# InterPals: 117
# Other app: 4599
# ----- Technical ----
# Some messages not delivered: 735
# Some photos not delivered: 401
# Audio messages wouldn't play: 274
# The app froze or crashed: 999
# I didn't receive notifications: 596
# Messages or chats were out of order: 512
# Audio messages failed to send: 302
# Audio or video quality was really bad: 322
# Other technical problem: 309
# Total: 147001
# Android: 83934
# iOS: 63067
# Total KO: 5607
# ----------KO----------
# -
# Mainly one language: 4794
# Didn't develop into meaningful convo: 16403
# The app is not what I expected: 14497
# There were too many scammers // fake profiles: 5887
# I couldn't find anyone to talk to: 20365
# The app didn't help me much with my language learning: 11834
# I received too many messages on Tandem: 5557
# I received too many calls on Tandem that I didn't want to take: 2684
# Someone offended or annoyed me: 4820
# I had technical problems using the app: 3225:Android: 1836 // 2.12251881481% :iOS: 1389 // 2.10113906243%
# Takes too much space: 5946:Android: 3604 // 4.16642582167%:iOS: 2055 // 3.10859666904%
# App drains battery: 4658:Android: 2603 // 3.00921376631%:iOS: 2055 // 3.10859666904%
# Too many push notifications: 3171:Android: 1866 // 2.15720049479%:iOS: 1305 // 1.97407233727%
# The app was confusing: 4497
# Not currently learning a lang: 9057
# Don't have time: 30978
# Want to change profile info: 5043
# Want to start a new account: 13533
# I am still a beginner: 11244
# It felt like a dating app: 15642
# Didn't want to pay for pro: 8017
# Using a different app: 4743
# Other: 5837
# -
# HelloTalk: 1714
# Speaky: 309
# Fylp: 121
# iTalki: 179
# OpenTalk: 108
# Lingebe: 92
# Bilingua: 127
# HelloPal: 130
# Duolingo: 1199
# Ablo: 170
# InterPals: 122
# Other app: 4795
# ----- Technical ----
# Some messages not delivered: 749
# Some photos not delivered: 408
# Audio messages wouldn't play: 280
# The app froze or crashed: 1025
# I didn't receive notifications: 609
# Messages or chats were out of order: 522
# Audio messages failed to send: 308
# Audio or video quality was really bad: 330
# Other technical problem: 316
# Total: 152608
# Android: 86501
# iOS: 66107
# Total PT: 10706
# ----------PT----------
# -
# Mainly one language: 4988
# Didn't develop into meaningful convo: 18108
# The app is not what I expected: 15472
# There were too many scammers // fake profiles: 6236
# I couldn't find anyone to talk to: 21779
# The app didn't help me much with my language learning: 12569
# I received too many messages on Tandem: 5760
# I received too many calls on Tandem that I didn't want to take: 2829
# Someone offended or annoyed me: 5126
# I had technical problems using the app: 3382:Android: 1948 // 2.06242324143% :iOS: 1434 // 2.08242572101%
# Takes too much space: 6463:Android: 3994 // 4.22860288824%:iOS: 2124 // 3.08442972902%
# App drains battery: 4883:Android: 2759 // 2.92106043281%:iOS: 2124 // 3.08442972902%
# Too many push notifications: 3312:Android: 1982 // 2.09842036167%:iOS: 1330 // 1.93139902994%
# The app was confusing: 4812
# Not currently learning a lang: 9584
# Don't have time: 33118
# Want to change profile info: 5287
# Want to start a new account: 14451
# I am still a beginner: 12190
# It felt like a dating app: 16657
# Didn't want to pay for pro: 8526
# Using a different app: 5018
# Other: 6452
# -
# HelloTalk: 1772
# Speaky: 330
# Fylp: 128
# iTalki: 194
# OpenTalk: 114
# Lingebe: 95
# Bilingua: 130
# HelloPal: 135
# Duolingo: 1293
# Ablo: 194
# InterPals: 129
# Other app: 4989
# ----- Technical ----
# Some messages not delivered: 793
# Some photos not delivered: 423
# Audio messages wouldn't play: 293
# The app froze or crashed: 1069
# I didn't receive notifications: 639
# Messages or chats were out of order: 549
# Audio messages failed to send: 317
# Audio or video quality was really bad: 347
# Other technical problem: 346
# Total: 163314
# Android: 94452
# iOS: 68862
# Total RU: 9165
# ----------RU----------
# -
# Mainly one language: 5276
# Didn't develop into meaningful convo: 18933
# The app is not what I expected: 16284
# There were too many scammers // fake profiles: 6509
# I couldn't find anyone to talk to: 23145
# The app didn't help me much with my language learning: 13400
# I received too many messages on Tandem: 6045
# I received too many calls on Tandem that I didn't want to take: 2993
# Someone offended or annoyed me: 5298
# I had technical problems using the app: 3563:Android: 2066 // 2.0607451% :iOS: 1497 // 2.07271821001%
# Takes too much space: 6872:Android: 4263 // 4.25215699965%:iOS: 2204 // 3.05161719096%
# App drains battery: 5096:Android: 2892 // 2.8846441574%:iOS: 2204 // 3.05161719096%
# Too many push notifications: 3470:Android: 2091 // 2.08568151214%:iOS: 1379 // 1.9093376163%
# The app was confusing: 5005
# Not currently learning a lang: 10170
# Don't have time: 35041
# Want to change profile info: 5617
# Want to start a new account: 15580
# I am still a beginner: 13006
# It felt like a dating app: 17517
# Didn't want to pay for pro: 9233
# Using a different app: 5317
# Other: 6710
# -
# HelloTalk: 1847
# Speaky: 369
# Fylp: 136
# iTalki: 206
# OpenTalk: 119
# Lingebe: 98
# Bilingua: 135
# HelloPal: 143
# Duolingo: 1355
# Ablo: 212
# InterPals: 147
# Other app: 5277
# ----- Technical ----
# Some messages not delivered: 819
# Some photos not delivered: 445
# Audio messages wouldn't play: 308
# The app froze or crashed: 1138
# I didn't receive notifications: 666
# Messages or chats were out of order: 561
# Audio messages failed to send: 335
# Audio or video quality was really bad: 369
# Other technical problem: 368
# Total: 172479
# Android: 100255
# iOS: 72224
# Total ZHS: 3918
# ----------ZHS----------
# -
# Mainly one language: 5401
# Didn't develop into meaningful convo: 19376
# The app is not what I expected: 16798
# There were too many scammers // fake profiles: 6734
# I couldn't find anyone to talk to: 23961
# The app didn't help me much with my language learning: 13746
# I received too many messages on Tandem: 6107
# I received too many calls on Tandem that I didn't want to take: 3049
# Someone offended or annoyed me: 5494
# I had technical problems using the app: 3675:Android: 2169 // 2.0867808351% :iOS: 1506 // 2.07847412948%
# Takes too much space: 7023:Android: 4406 // 4.23898402925%:iOS: 2206 // 3.04456436231%
# App drains battery: 5143:Android: 2937 // 2.82566865499%:iOS: 2206 // 3.04456436231%
# Too many push notifications: 3529:Android: 2145 // 2.06369059073%:iOS: 1384 // 1.91009840319%
# The app was confusing: 5180
# Not currently learning a lang: 10353
# Don't have time: 35788
# Want to change profile info: 5844
# Want to start a new account: 16094
# I am still a beginner: 13520
# It felt like a dating app: 17768
# Didn't want to pay for pro: 9654
# Using a different app: 5393
# Other: 6848
# -
# HelloTalk: 1875
# Speaky: 371
# Fylp: 137
# iTalki: 208
# OpenTalk: 124
# Lingebe: 98
# Bilingua: 140
# HelloPal: 148
# Duolingo: 1363
# Ablo: 218
# InterPals: 150
# Other app: 5402
# ----- Technical ----
# Some messages not delivered: 838
# Some photos not delivered: 479
# Audio messages wouldn't play: 325
# The app froze or crashed: 1171
# I didn't receive notifications: 699
# Messages or chats were out of order: 579
# Audio messages failed to send: 349
# Audio or video quality was really bad: 386
# Other technical problem: 385
# Total: 176397
# Android: 103940
# iOS: 72457
# Total ZHT: 373
# ----------ZHT----------
# -
# Mainly one language: 5420
# Didn't develop into meaningful convo: 19426
# The app is not what I expected: 16858
# There were too many scammers // fake profiles: 6760
# I couldn't find anyone to talk to: 24036
# The app didn't help me much with my language learning: 13790
# I received too many messages on Tandem: 6122
# I received too many calls on Tandem that I didn't want to take: 3052
# Someone offended or annoyed me: 5518
# I had technical problems using the app: 3680:Android: 2172 // 2.08421295052% :iOS: 1508 // 2.07833733014%
# Takes too much space: 7040:Android: 4420 // 4.24135416267%:iOS: 2208 // 3.04308277516%
# App drains battery: 5150:Android: 2942 // 2.82309139063%:iOS: 2208 // 3.04308277516%
# Too many push notifications: 3534:Android: 2148 // 2.06118297317%:iOS: 1386 // 1.91019598115%
# The app was confusing: 5194
# Not currently learning a lang: 10372
# Don't have time: 35854
# Want to change profile info: 5868
# Want to start a new account: 16130
# I am still a beginner: 13564
# It felt like a dating app: 17800
# Didn't want to pay for pro: 9686
# Using a different app: 5404
# Other: 6854
# -
# HelloTalk: 1880
# Speaky: 372
# Fylp: 138
# iTalki: 208
# OpenTalk: 124
# Lingebe: 100
# Bilingua: 140
# HelloPal: 148
# Duolingo: 1364
# Ablo: 218
# InterPals: 150
# Other app: 5421
# ----- Technical ----
# Some messages not delivered: 838
# Some photos not delivered: 480
# Audio messages wouldn't play: 326
# The app froze or crashed: 1172
# I didn't receive notifications: 702
# Messages or chats were out of order: 580
# Audio messages failed to send: 350
# Audio or video quality was really bad: 388
# Other technical problem: 386
# Total: 176770
# Android: 104212
# iOS: 72558

# %%
# run analyse function on device_type
devices = ["df_android", "df_ios"]
for device in devices:
    print_results("device")
    reset_values()
    analyse(device)
# Out:
# ----------df_android----------
# -
# Mainly one language: 5420
# Didn't develop into meaningful convo: 19426
# The app is not what I expected: 16858
# There were too many scammers // fake profiles: 6760
# I couldn't find anyone to talk to: 24036
# The app didn't help me much with my language learning: 13790
# I received too many messages on Tandem: 6122
# I received too many calls on Tandem that I didn't want to take: 3052
# Someone offended or annoyed me: 5518
# I had technical problems using the app: 3680:Android: 2172 // 2.08421295052% :iOS: 1508 // 2.07833733014%
# Takes too much space: 7040:Android: 4420 // 4.24135416267%:iOS: 2208 // 3.04308277516%
# App drains battery: 5150:Android: 2942 // 2.82309139063%:iOS: 2208 // 3.04308277516%
# Too many push notifications: 3534:Android: 2148 // 2.06118297317%:iOS: 1386 // 1.91019598115%
# The app was confusing: 5194
# Not currently learning a lang: 10372
# Don't have time: 35854
# Want to change profile info: 5868
# Want to start a new account: 16130
# I am still a beginner: 13564
# It felt like a dating app: 17800
# Didn't want to pay for pro: 9686
# Using a different app: 5404
# Other: 6854
# -
# HelloTalk: 1880
# Speaky: 372
# Fylp: 138
# iTalki: 208
# OpenTalk: 124
# Lingebe: 100
# Bilingua: 140
# HelloPal: 148
# Duolingo: 1364
# Ablo: 218
# InterPals: 150
# Other app: 5421
# ----- Technical ----
# Some messages not delivered: 838
# Some photos not delivered: 480
# Audio messages wouldn't play: 326
# The app froze or crashed: 1172
# I didn't receive notifications: 702
# Messages or chats were out of order: 580
# Audio messages failed to send: 350
# Audio or video quality was really bad: 388
# Other technical problem: 386
# Total: 176770
# Android: 104212
# iOS: 72558
# Total df_android: 67110
# ----------df_ios----------
# -
# Mainly one language: 7561
# Didn't develop into meaningful convo: 27185
# The app is not what I expected: 22844
# There were too many scammers // fake profiles: 9222
# I couldn't find anyone to talk to: 34021
# The app didn't help me much with my language learning: 19269
# I received too many messages on Tandem: 8212
# I received too many calls on Tandem that I didn't want to take: 4089
# Someone offended or annoyed me: 7682
# I had technical problems using the app: 5103:Android: 3595 // 2.0983878311% :iOS: 1508 // 2.07833733014%
# Takes too much space: 9842:Android: 7222 // 4.21545394053%:iOS: 2208 // 3.04308277516%
# App drains battery: 7083:Android: 4875 // 2.84551896429%:iOS: 2208 // 3.04308277516%
# Too many push notifications: 4933:Android: 3547 // 2.07037041361%:iOS: 1386 // 1.91019598115%
# The app was confusing: 7062
# Not currently learning a lang: 14430
# Don't have time: 49395
# Want to change profile info: 8306
# Want to start a new account: 22820
# I am still a beginner: 19197
# It felt like a dating app: 23904
# Didn't want to pay for pro: 13377
# Using a different app: 7497
# Other: 10206
# -
# HelloTalk: 2473
# Speaky: 547
# Fylp: 196
# iTalki: 285
# OpenTalk: 174
# Lingebe: 154
# Bilingua: 188
# HelloPal: 204
# Duolingo: 1906
# Ablo: 337
# InterPals: 209
# Other app: 7562
# ----- Technical ----
# Some messages not delivered: 1189
# Some photos not delivered: 718
# Audio messages wouldn't play: 475
# The app froze or crashed: 1579
# I didn't receive notifications: 1015
# Messages or chats were out of order: 819
# Audio messages failed to send: 497
# Audio or video quality was really bad: 563
# Other technical problem: 533
# Total: 243880
# Android: 171322
# iOS: 72558
# Total df_ios: 51071
